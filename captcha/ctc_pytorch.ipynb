# %% [markdown]
# # 导入必要的库
#
# 我们需要导入一个叫 [captcha](https://github.com/lepture/captcha/) 的库来生成验证码。
#
# 我们生成验证码的字符由数字和大写字母组成。
#
# ```sh
# pip install captcha numpy matplotlib torch torchvision tqdm
# ```

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms.functional import to_tensor, to_pil_image

from tqdm import tqdm
import random
import numpy as np
from collections import OrderedDict
from PIL import Image
import string
characters = '-' + string.digits + string.ascii_uppercase
width, height, n_len, n_classes = 200, 50, 6, len(characters)
n_input_length = 12
print(characters, width, height, n_len, n_classes)
# Out:
# -0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ 200 50 6 37

# %% [markdown]
# # 搭建数据集

# %%
import os
file_list = [x.split('.')[0] for x in  os.listdir("./img")]
#file_list = [x for x in file_list if len(x)==4 ]
random.shuffle(file_list)

# %%
class CaptchaDataset(Dataset):
    def __init__(self, characters, length, width, height, input_length, label_length):
        super(CaptchaDataset, self).__init__()
        self.characters = characters
        self.length = length
        self.width = width
        self.height = height
        self.input_length = input_length
        self.label_length = label_length
        self.n_class = len(characters)

    def __len__(self):
        return self.length
    
    def __getitem__(self, index):
        lable = file_list.pop()
        image = to_tensor(Image.open("./img/"+lable+".jpg"))
        lable = lable.ljust(self.label_length, characters[0])
        target = torch.tensor([self.characters.find(x) for x in lable], dtype=torch.long)
        input_length = torch.full(size=(1, ), fill_value=self.input_length, dtype=torch.long)
        target_length = torch.full(size=(1, ), fill_value=self.label_length, dtype=torch.long)
        return image, target, input_length, target_length

# %% [markdown]
# from zipfile import ZipFile
# img_zip = ZipFile("img.zip")
# file_list = [x.filename.split('.')[0] for x in img_zip.infolist()]
# random.shuffle(file_list)

# %% [markdown]
# class CaptchaDataset(Dataset):
#     def __init__(self, characters, length, width, height, input_length, label_length):
#         super(CaptchaDataset, self).__init__()
#         self.characters = characters
#         self.length = length
#         self.width = width
#         self.height = height
#         self.input_length = input_length
#         self.label_length = label_length
#         self.n_class = len(characters)
#
#     def __len__(self):
#         return self.length
#
#     def __getitem__(self, index):
#         lable = file_list.pop()
#         img_file = img_zip.open(lable+".jpg","r")
#         image = to_tensor(Image.open(img_file).convert('RGB'))
#         lable = lable.ljust(self.label_length, characters[0])
#         target = torch.tensor([self.characters.find(x) for x in lable], dtype=torch.long)
#         input_length = torch.full(size=(1, ), fill_value=self.input_length, dtype=torch.long)
#         target_length = torch.full(size=(1, ), fill_value=self.label_length, dtype=torch.long)
#         return image, target, input_length, target_length

# %% [markdown]
# # 测试数据集

# %%
dataset = CaptchaDataset(characters, 1, width, height, n_input_length, n_len)
image, target, input_length, label_length = dataset[0]
print(''.join([characters[x] for x in target]), input_length, label_length)
to_pil_image(image)
# Out:
# JCEAW6 tensor([12]) tensor([6])
# <PIL.Image.Image image mode=RGB size=200x50 at 0x7F44783A4E50>

# %% [markdown]
# # 初始化数据集生成器

# %%
batch_size = 128
train_set = CaptchaDataset(characters, 1000 * batch_size, width, height, n_input_length, n_len)
valid_set = CaptchaDataset(characters, 100 * batch_size, width, height, n_input_length, n_len)
train_loader = DataLoader(train_set, batch_size=batch_size, num_workers=12)
valid_loader = DataLoader(valid_set, batch_size=batch_size, num_workers=12)

# %% [markdown]
# # 搭建模型

# %%
class Model(nn.Module):
    def __init__(self, n_classes, input_shape):
        super(Model, self).__init__()
        self.input_shape = input_shape
        channels = [32, 64, 128, 256, 256]
        layers = [2, 2, 2, 2, 2]
        kernels = [3, 3, 3, 3, 3]
        pools = [2, 2, 2, 2, (2, 1)]
        modules = OrderedDict()
        
        def cba(name, in_channels, out_channels, kernel_size):
            modules[f'conv{name}'] = nn.Conv2d(in_channels, out_channels, kernel_size,
                                               padding=(1, 1) if kernel_size == 3 else 0)
            modules[f'bn{name}'] = nn.BatchNorm2d(out_channels)
            modules[f'relu{name}'] = nn.ReLU(inplace=True)
        
        last_channel = 3
        for block, (n_channel, n_layer, n_kernel, k_pool) in enumerate(zip(channels, layers, kernels, pools)):
            for layer in range(1, n_layer + 1):
                cba(f'{block+1}{layer}', last_channel, n_channel, n_kernel)
                last_channel = n_channel
            modules[f'pool{block + 1}'] = nn.MaxPool2d(k_pool)
        modules[f'dropout'] = nn.Dropout(0.25, inplace=True)
        
        self.cnn = nn.Sequential(modules)
        self.lstm = nn.LSTM(input_size=self.infer_features(), hidden_size=128, num_layers=2, bidirectional=True)
        self.fc = nn.Linear(in_features=256, out_features=n_classes)
    
    def infer_features(self):
        x = torch.zeros((1,)+self.input_shape)
        x = self.cnn(x)
        x = x.reshape(x.shape[0], -1, x.shape[-1])
        return x.shape[1]

    def forward(self, x):
        x = self.cnn(x)
        x = x.reshape(x.shape[0], -1, x.shape[-1])
        x = x.permute(2, 0, 1)
        x, _ = self.lstm(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ## 测试模型输出尺寸

# %%
model = Model(n_classes, input_shape=(3, height, width))
inputs = torch.zeros((32, 3, height, width))
outputs = model(inputs)
outputs.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# torch.Size([12, 32, 37])

# %% [markdown]
# ## 初始化模型

# %%
model = Model(n_classes, input_shape=(3, height, width))
model = model.cuda()
model
# Out:
# Model(
#   (cnn): Sequential(
#     (conv11): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn11): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu11): ReLU(inplace=True)
#     (conv12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn12): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu12): ReLU(inplace=True)
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv21): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu21): ReLU(inplace=True)
#     (conv22): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn22): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu22): ReLU(inplace=True)
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv31): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn31): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu31): ReLU(inplace=True)
#     (conv32): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn32): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu32): ReLU(inplace=True)
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv41): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn41): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu41): ReLU(inplace=True)
#     (conv42): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn42): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu42): ReLU(inplace=True)
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv51): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn51): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu51): ReLU(inplace=True)
#     (conv52): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn52): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu52): ReLU(inplace=True)
#     (pool5): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (dropout): Dropout(p=0.25, inplace=True)
#   )
#   (lstm): LSTM(256, 128, num_layers=2, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=37, bias=True)
# )

# %% [markdown]
# # 解码函数和准确率计算函数

# %%
def decode(sequence):
    a = ''.join([characters[x] for x in sequence])
    s = ''.join([x for j, x in enumerate(a[:-1]) if x != characters[0] and x != a[j+1]])
    if len(s) == 0:
        return ''
    if a[-1] != characters[0] and s[-1] != a[-1]:
        s += a[-1]
    return s

def decode_target(sequence):
    return ''.join([characters[x] for x in sequence]).replace(characters[0], '')

def calc_acc(target, output):
    output_argmax = output.detach().permute(1, 0, 2).argmax(dim=-1)
    target = target.cpu().numpy()
    output_argmax = output_argmax.cpu().numpy()
    a = np.array([decode_target(true) == decode(pred) for true, pred in zip(target, output_argmax)])
    return a.mean()

# %% [markdown]
# # 训练模型

# %%
def train(model, optimizer, epoch, dataloader):
    model.train()
    loss_mean = 0
    acc_mean = 0
    with tqdm(dataloader) as pbar:
        for batch_index, (data, target, input_lengths, target_lengths) in enumerate(pbar):
            data, target = data.cuda(), target.cuda()
            
            optimizer.zero_grad()
            output = model(data)
            
            output_log_softmax = F.log_softmax(output, dim=-1)
            loss = F.ctc_loss(output_log_softmax, target, input_lengths, target_lengths)
            
            loss.backward()
            optimizer.step()

            loss = loss.item()
            acc = calc_acc(target, output)
            
            if batch_index == 0:
                loss_mean = loss
                acc_mean = acc
            
            loss_mean = 0.1 * loss + 0.9 * loss_mean
            acc_mean = 0.1 * acc + 0.9 * acc_mean
            
            pbar.set_description(f'Epoch: {epoch} Loss: {loss_mean:.4f} Acc: {acc_mean:.4f} ')

def valid(model, optimizer, epoch, dataloader):
    model.eval()
    with tqdm(dataloader) as pbar, torch.no_grad():
        loss_sum = 0
        acc_sum = 0
        for batch_index, (data, target, input_lengths, target_lengths) in enumerate(pbar):
            data, target = data.cuda(), target.cuda()
            
            output = model(data)
            output_log_softmax = F.log_softmax(output, dim=-1)
            loss = F.ctc_loss(output_log_softmax, target, input_lengths, target_lengths)
            
            loss = loss.item()
            acc = calc_acc(target, output)
            
            loss_sum += loss
            acc_sum += acc
            
            loss_mean = loss_sum / (batch_index + 1)
            acc_mean = acc_sum / (batch_index + 1)
            
            pbar.set_description(f'Test : {epoch} Loss: {loss_mean:.4f} Acc: {acc_mean:.4f} ')

# %%
optimizer = torch.optim.Adam(model.parameters(), 1e-3, amsgrad=True)
epochs = 30
for epoch in range(1, epochs + 1):
    train(model, optimizer, epoch, train_loader)
    valid(model, optimizer, epoch, valid_loader)
# Out:
# Epoch: 1 Loss: -0.1522 Acc: 0.8886 : 100%|██████████| 1000/1000 [06:03<00:00,  2.75it/s]
# Test : 1 Loss: 0.0385 Acc: 0.6597 : 100%|██████████| 100/100 [00:15<00:00,  6.51it/s]
# Epoch: 2 Loss: -0.2665 Acc: 0.9531 : 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
# Test : 2 Loss: -0.2095 Acc: 0.8759 : 100%|██████████| 100/100 [00:15<00:00,  6.50it/s]
# Epoch: 3 Loss: -0.3099 Acc: 0.9656 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 3 Loss: -0.2882 Acc: 0.9222 : 100%|██████████| 100/100 [00:15<00:00,  6.47it/s]
# Epoch: 4 Loss: -0.3396 Acc: 0.9763 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 4 Loss: -0.3170 Acc: 0.9331 : 100%|██████████| 100/100 [00:15<00:00,  6.45it/s]
# Epoch: 5 Loss: -0.3599 Acc: 0.9928 : 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
# Test : 5 Loss: -0.3560 Acc: 0.9616 : 100%|██████████| 100/100 [00:15<00:00,  6.52it/s]
# Epoch: 6 Loss: -0.3635 Acc: 0.9828 : 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
# Test : 6 Loss: -0.3675 Acc: 0.9663 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 7 Loss: -0.3741 Acc: 0.9915 : 100%|██████████| 1000/1000 [06:04<00:00,  2.74it/s]
# Test : 7 Loss: -0.3788 Acc: 0.9691 : 100%|██████████| 100/100 [00:15<00:00,  6.47it/s]
# Epoch: 8 Loss: -0.3750 Acc: 0.9912 : 100%|██████████| 1000/1000 [06:04<00:00,  2.74it/s]
# Test : 8 Loss: -0.3878 Acc: 0.9825 : 100%|██████████| 100/100 [00:15<00:00,  6.52it/s]
# Epoch: 9 Loss: -0.3787 Acc: 0.9907 : 100%|██████████| 1000/1000 [06:04<00:00,  2.74it/s]
# Test : 9 Loss: -0.3951 Acc: 0.9838 : 100%|██████████| 100/100 [00:15<00:00,  6.51it/s]
# Epoch: 10 Loss: -0.3791 Acc: 0.9944 : 100%|██████████| 1000/1000 [06:04<00:00,  2.74it/s]
# Test : 10 Loss: -0.4018 Acc: 0.9941 : 100%|██████████| 100/100 [00:15<00:00,  6.50it/s]
# Epoch: 11 Loss: -0.3824 Acc: 0.9954 : 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
# Test : 11 Loss: -0.3991 Acc: 0.9872 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]
# Epoch: 12 Loss: -0.3864 Acc: 0.9978 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 12 Loss: -0.4066 Acc: 0.9938 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]
# Epoch: 13 Loss: -0.3883 Acc: 0.9978 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 13 Loss: -0.4048 Acc: 0.9881 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]
# Epoch: 14 Loss: -0.3863 Acc: 0.9969 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 14 Loss: -0.4040 Acc: 0.9912 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 15 Loss: -0.3923 Acc: 0.9884 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 15 Loss: -0.4051 Acc: 0.9800 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]
# Epoch: 16 Loss: -0.3989 Acc: 0.9926 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 16 Loss: -0.4122 Acc: 0.9847 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 17 Loss: -0.4020 Acc: 0.9925 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 17 Loss: -0.4202 Acc: 0.9894 : 100%|██████████| 100/100 [00:15<00:00,  6.47it/s]
# Epoch: 18 Loss: -0.4076 Acc: 0.9893 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 18 Loss: -0.4063 Acc: 0.9625 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]
# Epoch: 19 Loss: -0.4183 Acc: 0.9954 : 100%|██████████| 1000/1000 [06:05<00:00,  2.73it/s]
# Test : 19 Loss: -0.4376 Acc: 0.9878 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 20 Loss: -0.4223 Acc: 0.9963 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 20 Loss: -0.4342 Acc: 0.9872 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 21 Loss: -0.4205 Acc: 0.9930 : 100%|██████████| 1000/1000 [06:08<00:00,  2.72it/s]
# Test : 21 Loss: -0.4407 Acc: 0.9900 : 100%|██████████| 100/100 [00:15<00:00,  6.34it/s]
# Epoch: 22 Loss: -0.4827 Acc: 0.9972 :   6%|▌         | 60/1000 [00:23<06:03,  2.59it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-4aa98fc4a0ab> in <module>
#       2 epochs = 30
#       3 for epoch in range(1, epochs + 1):
# ----> 4     train(model, optimizer, epoch, train_loader)
#       5     valid(model, optimizer, epoch, valid_loader)
#
# <ipython-input-10-4dcd70a86e84> in train(model, optimizer, epoch, dataloader)
#      16             optimizer.step()
#      17
# ---> 18             loss = loss.item()
#      19             acc = calc_acc(target, output)
#      20
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.Adam(model.parameters(), 1e-4, amsgrad=True)
epochs = 5
for epoch in range(1, epochs + 1):
    train(model, optimizer, epoch, train_loader)
    valid(model, optimizer, epoch, valid_loader)
# Out:
# Epoch: 1 Loss: -0.4258 Acc: 0.9969 : 100%|██████████| 1000/1000 [06:07<00:00,  2.72it/s]
# Test : 1 Loss: -0.4503 Acc: 0.9978 : 100%|██████████| 100/100 [00:15<00:00,  6.45it/s]
# Epoch: 2 Loss: -0.4281 Acc: 1.0000 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 2 Loss: -0.4499 Acc: 0.9981 : 100%|██████████| 100/100 [00:15<00:00,  6.46it/s]
# Epoch: 3 Loss: -0.4282 Acc: 0.9969 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 3 Loss: -0.4524 Acc: 1.0000 : 100%|██████████| 100/100 [00:15<00:00,  6.46it/s]
# Epoch: 4 Loss: -0.4289 Acc: 0.9993 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 4 Loss: -0.4532 Acc: 1.0000 : 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Epoch: 5 Loss: -0.4288 Acc: 0.9991 : 100%|██████████| 1000/1000 [06:06<00:00,  2.73it/s]
# Test : 5 Loss: -0.4535 Acc: 1.0000 : 100%|██████████| 100/100 [00:15<00:00,  6.48it/s]

# %% [markdown]
# # 测试模型输出

# %%
model.eval()
do = True
while do or decode_target(target) == decode(output_argmax[0]):
    do = False
    image, target, input_length, label_length = dataset[0]
    print('true:', decode_target(target))

    output = model(image.unsqueeze(0).cuda())
    output_argmax = output.detach().permute(1, 0, 2).argmax(dim=-1)
    print('pred:', decode(output_argmax[0]))
to_pil_image(image)
# Out:
# true: EN8CA
# pred: EN8CA
# true: YDTXT
# pred: YDTXT
# true: TEMTD
# pred: TEMTD
# true: EPCT5E
# pred: EPCT5E
# true: KKYPE
# pred: KKYPE
# true: RKDC
# pred: RKDC
# true: TM5PKU
# pred: TM5PKU
# true: 8CB4
# pred: 8CB4
# true: XCBYV9
# pred: XCBYV9
# true: CTJTPE
# pred: CTJTPE
# true: UH53VB
# pred: UH53VB
# true: AK389A
# pred: AK389A
# true: SMJADH
# pred: SMJADH
# true: T6JM
# pred: T6JM
# true: XAPWRX
# pred: XAPWRX
# true: 5KBE
# pred: 5KBE
# true: HP5J
# pred: HP5J
# true: 96TU
# pred: 96TU
# true: E63Y3
# pred: E63Y3
# true: TS6A
# pred: TS6A
# true: TU5PRV
# pred: TU5PRV
# true: 9V66JW
# pred: 9V66JW
# true: RSVC
# pred: RSVC
# true: V65R
# pred: V65R
# true: MJVK
# pred: MJVK
# true: 5Y9KB
# pred: 5Y9KB
# true: 3PH8
# pred: 3PH8
# true: XXVTNX
# pred: XXVTNX
# true: V5YX
# pred: V5YX
# true: 5A9J6
# pred: 5A9J6
# true: MPMR
# pred: MPMR
# true: YB3DC
# pred: YB3DC
# true: UJN4B
# pred: UJN4B
# true: W9HNMY
# pred: W9HNMY
# true: KTDMX
# pred: KTDMX
# true: VNWV
# pred: VNWV
# true: B5J8
# pred: B5J8
# true: 6X66
# pred: 6X66
# true: WTTPK
# pred: WTTPK
# true: RPMC
# pred: RPMC
# true: 5XSKRW
# pred: 5XSKRW
# true: SSHR
# pred: SSHR
# true: CYRBKC
# pred: CYRBKC
# true: VSDN
# pred: VSDN
# true: N965
# pred: N965
# true: AS6XT4
# pred: AS6XT4
# true: C6CSM
# pred: C6CSM
# true: 3N3X
# pred: 3N3X
# true: 6XX8
# pred: 6XX8
# true: X34M
# pred: X34M
# true: 36TBHW
# pred: 36TBHW
# true: W8U9
# pred: W8U9
# true: 5WYP
# pred: 5WYP
# true: BPXM
# pred: BPXM
# true: JJJD9
# pred: JJJD9
# true: 4J5YAW
# pred: 4J5YAW
# true: TVEB
# pred: TVEB
# true: UH6NP9
# pred: UH6NP9
# true: 59MM4H
# pred: 59MM4H
# true: HUHD
# pred: HUHD
# true: 6TC3
# pred: 6TC3
# true: CHV3
# pred: CHV3
# true: KTYHK5
# pred: KTYHK5
# true: TNM8D
# pred: TNM8D
# true: VKX38
# pred: VKX38
# true: SHPNMW
# pred: SHPNMW
# true: YUXMHP
# pred: YUXMHP
# true: XBS5
# pred: XBS5
# true: DW3HYN
# pred: DW3HYN
# true: 6BRJR
# pred: 6BRJR
# true: D5RR9K
# pred: D5RR9K
# true: NJMT
# pred: NJMT
# true: 5RSUT6
# pred: 5RSUT6
# true: 33DUWC
# pred: 33DUWC
# true: BCV854
# pred: BCV854
# true: 8AXS
# pred: 8AXS
# true: NPKJ
# pred: NPKJ
# true: X3T6SE
# pred: X3T6SE
# true: JKXUD
# pred: JKXUD
# true: 8BDTX
# pred: 8BDTX
# true: WU8KK
# pred: WU8KK
# true: Y3SYY
# pred: Y3SYY
# true: UXHYNP
# pred: UXHYNP
# true: 85KD
# pred: 85KD
# true: YW3UNJ
# pred: YW3UNJ
# true: MRCB3
# pred: MRCB3
# true: E6CTH
# pred: E6CTH
# true: B3N99
# pred: B3N99
# true: DPM39
# pred: DPM39
# true: 5VDK56
# pred: 5VDK56
# true: JHTC
# pred: JHTC
# true: KPESH
# pred: KPESH
# true: YT4BMR
# pred: YT4BMR
# true: XKK64
# pred: XKK64
# true: 3534NY
# pred: 3534NY
# true: KYREVS
# pred: KYREVS
# true: AHD3Y
# pred: AHD3Y
# true: B6JB
# pred: B6JB
# true: CKUTU
# pred: CKUTU
# true: T8P5
# pred: T8P5
# true: RCB9
# pred: RCB9
# true: DKXT
# pred: DKXT
# true: DS6K3H
# pred: DS6K3H
# true: VDVD
# pred: VDVD
# true: A4BNV9
# pred: A4BNV9
# true: YTM4XH
# pred: YTM4XH
# true: Y6CJ
# pred: Y6CJ
# true: VYEUB
# pred: VYEUB
# true: WSYKWH
# pred: WSYKWH
# true: R85YA
# pred: R85YA
# true: 8BDYAU
# pred: 8BDYAU
# true: EBR5B
# pred: EBR5B
# true: ANAN6
# pred: ANAN6
# true: DU359
# pred: DU359
# true: SB8A
# pred: SB8A
# true: VT4J
# pred: VT4J
# true: W5BD3
# pred: W5BD3
# true: NVWP6R
# pred: NVWP6R
# true: 638JUB
# pred: 638JUB
# true: TESTA
# pred: TESTA
# true: NH6JS
# pred: NH6JS
# true: KP39J
# pred: KP39J
# true: U55T
# pred: U55T
# true: RSJX4M
# pred: RSJX4M
# true: UAUK
# pred: UAUK
# true: DKUJ
# pred: DKUJ
# true: 56VRY
# pred: 56VRY
# true: CKXE6
# pred: CKXE6
# true: KKAM3
# pred: KKAM3
# true: 6N8BP
# pred: 6N8BP
# true: BJB4
# pred: BJB4
# true: HB8J
# pred: HB8J
# true: WYP6J
# pred: WYP6J
# true: 6JR9R
# pred: 6JR9R
# true: 3NJJ
# pred: 3NJJ
# true: 9JNP
# pred: 9JNP
# true: KKAJ
# pred: KKAJ
# true: 8XS5UC
# pred: 8XS5UC
# true: D4J4ET
# pred: D4J4ET
# true: K5WPS
# pred: K5WPS
# true: DXWPS
# pred: DXWPS
# true: M3XET
# pred: M3XET
# true: KYD6W6
# pred: KYD6W6
# true: NCKPC
# pred: NCKPC
# true: BDDX
# pred: BDDX
# true: A39X8E
# pred: A39X8E
# true: 685D
# pred: 685D
# true: YVNJ
# pred: YVNJ
# true: WRRX
# pred: WRRX
# true: 69UDAV
# pred: 69UDAV
# true: T8JM
# pred: T8JM
# true: 4B9DP
# pred: 4B9DP
# true: JP4TDB
# pred: JP4TDB
# true: 98VU
# pred: 98VU
# true: HCS6Y4
# pred: HCS6Y4
# true: YBT3
# pred: YBT3
# true: 6D6X
# pred: 6D6X
# true: DAM5
# pred: DAM5
# true: HMDCBB
# pred: HMDCBB
# true: DP49J
# pred: DP49J
# true: PVAUEK
# pred: PVAUEK
# true: 5KDVY8
# pred: 5KDVY8
# true: D9SNAE
# pred: D9SNAE
# true: UDT3
# pred: UDT3
# true: KDDS55
# pred: KDDS55
# true: RBS8
# pred: RBS8
# true: N3PJB
# pred: N3PJB
# true: J5BR6
# pred: J5BR6
# true: 5XCK
# pred: 5XCK
# true: H6DY
# pred: H6DY
# true: ASK8RU
# pred: ASK8RU
# true: JHDME
# pred: JHDME
# true: MU3A8
# pred: MU3A8
# true: 9YB3PE
# pred: 9YB3PE
# true: RUYS
# pred: RUYS
# true: CVNW8
# pred: CVNW8
# true: 4JBNA
# pred: 4JBNA
# true: N3W9S
# pred: N3W9S
# true: K8HE5
# pred: K8HE5
# true: USNMR
# pred: USNMR
# true: P33WY8
# pred: P33WY8
# true: 68AY
# pred: 68AY
# true: Y9EP
# pred: Y9EP
# true: K4VPAP
# pred: K4VPAP
# true: CPX9W
# pred: CPX9W
# true: WC389U
# pred: WC389U
# true: H883
# pred: H883
# true: DYP4
# pred: DYP4
# true: 349JCN
# pred: 349JCN
# true: E933X
# pred: E933X
# true: YHK8X
# pred: YHK8X
# true: DPJNW
# pred: DPJNW
# true: X8TEB
# pred: X8TEB
# true: Y6EWW4
# pred: Y6EWW4
# true: MHVJ
# pred: MHVJ
# true: AAMTE
# pred: AAMTE
# true: D9XMJ6
# pred: D9XMJ6
# true: XTPNHH
# pred: XTPNHH
# true: VHY8SM
# pred: VHY8SM
# true: VB89
# pred: VB89
# true: M8JXW9
# pred: M8JXW9
# true: HXRE9
# pred: HXRE9
# true: YT4YA
# pred: YT4YA
# true: 4VWWB6
# pred: 4VWWB6
# true: 9MYYME
# pred: 9MYYME
# true: KM8PW
# pred: KM8PW
# true: S63RXA
# pred: S63RXA
# true: VRWK44
# pred: VRWK44
# true: SXC6BN
# pred: SXC6BN
# true: S4AE
# pred: S4AE
# true: 3ADUV
# pred: 3ADUV
# true: JRXB6
# pred: JRXB6
# true: 6KCT
# pred: 6KCT
# true: WUUC
# pred: WUUC
# true: 36HNNT
# pred: 36HNNT
# true: 6RKK
# pred: 6RKK
# true: U5XU
# pred: U5XU
# true: NM49S
# pred: NM49S
# true: J3RPS3
# pred: J3RPS3
# true: 8YYRC
# pred: 8YYRC
# true: VRSHHY
# pred: VRSHHY
# true: PJHUYC
# pred: PJHUYC
# true: KMB3
# pred: KMB3
# true: 3R5CM
# pred: 3R5CM
# true: 9YAV5A
# pred: 9YAV5A
# true: DDCWRM
# pred: DDCWRM
# true: H54XV6
# pred: H54XV6
# true: WPYA
# pred: WPYA
# true: UDBXUN
# pred: UDBXUN
# true: H5EK3
# pred: H5EK3
# true: MDNX
# pred: MDNX
# true: 5Y8NWV
# pred: 5Y8NWV
# true: KA56X
# pred: KA56X
# true: ABPP
# pred: ABPP
# true: DCEK
# pred: DCEK
# true: ET4VEW
# pred: ET4VEW
# true: 4MN5
# pred: 4MN5
# true: HXYDK9
# pred: HXYDK9
# true: 3XJY
# pred: 3XJY
# true: 49AM
# pred: 49AM
# true: PJNBD
# pred: PJNBD
# true: VT4XH
# pred: VT4XH
# true: KVSM
# pred: KVSM
# true: VMXDDE
# pred: VMXDDE
# true: 63UV
# pred: 63UV
# true: N9XJ
# pred: N9XJ
# true: 8936A
# pred: 8936A
# true: 58WR
# pred: 58WR
# true: WYCK
# pred: WYCK
# true: NVJ6
# pred: NVJ6
# true: NRVUJA
# pred: NRVUJA
# true: C6BVN
# pred: C6BVN
# true: 8DD45
# pred: 8DD45
# true: DBJ99
# pred: DBJ99
# true: M6N4A
# pred: M6N4A
# true: E4C3
# pred: E4C3
# true: 489EA6
# pred: 489EA6
# true: SHCB
# pred: SHCB
# true: JUMUA
# pred: JUMUA
# true: WYPV8
# pred: WYPV8
# true: T8HP8
# pred: T8HP8
# true: WC9JT
# pred: WC9JT
# true: RK86
# pred: RK86
# true: DM385N
# pred: DM385N
# true: 9WHN
# pred: 9WHN
# true: X5TW6K
# pred: X5TW6K
# true: M8NC
# pred: M8NC
# true: THUJAN
# pred: THUJAN
# true: 36YPPY
# pred: 36YPPY
# true: J3J6
# pred: J3J6
# true: BE9HS
# pred: BE9HS
# true: R9D3
# pred: R9D3
# true: 5UXJP
# pred: 5UXJP
# true: VHDU
# pred: VHDU
# true: 8CE8
# pred: 8CE8
# true: 8U8J8K
# pred: 8U8J8K
# true: UACVB
# pred: UACVB
# true: M6AU58
# pred: M6AU58
# true: KPXX
# pred: KPXX
# true: ENJ6U
# pred: ENJ6U
# true: 569R6
# pred: 569R6
# true: YTEJV
# pred: YTEJV
# true: SJHU5
# pred: SJHU5
# true: BSSV
# pred: BSSV
# true: SRKW
# pred: SRKW
# true: B53B
# pred: B53B
# true: A53SD
# pred: A53SD
# true: Y3J5BD
# pred: Y3J5BD
# true: 63R9
# pred: 63R9
# true: JVS8
# pred: JVS8
# true: 6PVX6
# pred: 6PVX6
# true: BY6KT
# pred: BY6KT
# true: WNHN
# pred: WNHN
# true: XDC3
# pred: XDC3
# true: 88MA
# pred: 88MA
# true: HYTK
# pred: HYTK
# true: TNSEM8
# pred: TNSEM8
# true: E9DX
# pred: E9DX
# true: AN4PA
# pred: AN4PA
# true: 8K53T9
# pred: 8K53T9
# true: 9KR5
# pred: 9KR5
# true: UYYVPV
# pred: UYYVPV
# true: 9T5ED
# pred: 9T5ED
# true: W36EMS
# pred: W36EMS
# true: D4NNJ
# pred: D4NNJ
# true: DKRYN3
# pred: DKRYN3
# true: RJKB
# pred: RJKB
# true: 4RCVNW
# pred: 4RCVNW
# true: XMXXK
# pred: XMXXK
# true: AXU48
# pred: AXU48
# true: CC8SYD
# pred: CC8SYD
# true: DCKDU
# pred: DCKDU
# true: 6N9Y6U
# pred: 6N9Y6U
# true: 9B6D
# pred: 9B6D
# true: V4A4
# pred: V4A4
# true: 43VYXX
# pred: 43VYXX
# true: 9PJ3W4
# pred: 9PJ3W4
# true: WW3Y
# pred: WW3Y
# true: B8PB
# pred: B8PB
# true: NVNCP6
# pred: NVNCP6
# true: 8VRS5N
# pred: 8VRS5N
# true: AATWKJ
# pred: AATWKJ
# true: ETBK
# pred: ETBK
# true: JBJB
# pred: JBJB
# true: DUCWWT
# pred: DUCWWT
# true: JBBJED
# pred: JBBJED
# true: VEES36
# pred: VEES36
# true: REA8H4
# pred: REA8H4
# true: BTAY
# pred: BTAY
# true: 6MCU9B
# pred: 6MCU9B
# true: APBEY4
# pred: APBEY4
# true: 6VRH
# pred: 6VRH
# true: EYY3
# pred: EYY3
# true: DDN3
# pred: DDN3
# true: VHRBR
# pred: VHRBR
# true: NDXM3E
# pred: NDXM3E
# true: DNYU
# pred: DNYU
# true: NMYUS
# pred: NMYUS
# true: JRXR
# pred: JRXR
# true: M5M9SJ
# pred: M5M9SJ
# true: V8KNAJ
# pred: V8KNAJ
# true: CN4Y
# pred: CN4Y
# true: PTN63
# pred: PTN63
# true: ARPCNK
# pred: ARPCNK
# true: P4B6
# pred: P4B6
# true: 639J89
# pred: 639J89
# true: WHJ4SU
# pred: WHJ4SU
# true: TPUJ
# pred: TPUJ
# true: S9UXB
# pred: S9UXB
# true: EAWM
# pred: EAWM
# true: XSDP
# pred: XSDP
# true: 3CB6CA
# pred: 3CB6CA
# true: M4N43T
# pred: M4N43T
# true: BU4E
# pred: BU4E
# true: EK9TV
# pred: EK9TV
# true: HK5SW
# pred: HK5SW
# true: BNJCE
# pred: BNJCE
# true: VM3YX
# pred: VM3YX
# true: EAYHAH
# pred: EAYHAH
# true: NY8H
# pred: NY8H
# true: YWCRRP
# pred: YWCRRP
# true: PYBXD
# pred: PYBXD
# true: 5C5E
# pred: 5C5E
# true: 5VP98
# pred: 5VP98
# true: MXYSE
# pred: MXYSE
# true: 5E8SJ
# pred: 5E8SJ
# true: T9W9XP
# pred: T9W9XP
# true: 6483PV
# pred: 6483PV
# true: 6XKR6A
# pred: 6XKR6A
# true: CCYJ
# pred: CCYJ
# true: METM
# pred: METM
# true: XMPW
# pred: XMPW
# true: JA3JV
# pred: JA3JV
# true: W4XY
# pred: W4XY
# true: M5AT
# pred: M5AT
# true: 33T4S
# pred: 33T4S
# true: 9NCHUD
# pred: 9NCHUD
# true: 8XA8S
# pred: 8XA8S
# true: SVEMPT
# pred: SVEMPT
# true: 3U3PB
# pred: 3U3PB
# true: 3UVM
# pred: 3UVM
# true: 4WCKWV
# pred: 4WCKWV
# true: VJXMA
# pred: VJXMA
# true: PW6N
# pred: PW6N
# true: J6VP9
# pred: J6VP9
# true: 8KC6
# pred: 8KC6
# true: NTJ4C
# pred: NTJ4C
# true: SAJA
# pred: SAJA
# true: KE3V
# pred: KE3V
# true: 46VX
# pred: 46VX
# true: C5RA
# pred: C5RA
# true: H5VNB
# pred: H5VNB
# true: 55K9
# pred: 55K9
# true: JBHSW
# pred: JBHSW
# true: T8YJV
# pred: T8YJV
# true: RSTSB4
# pred: RSTSB4
# true: 9UK3W6
# pred: 9UK3W6
# true: KTYR3
# pred: KTYR3
# true: 4S3W
# pred: 4S3W
# true: MU4AH
# pred: MU4AH
# true: R9MD
# pred: R9MD
# true: KASYUU
# pred: KASYUU
# true: NRPV
# pred: NRPV
# true: XTYA
# pred: XTYA
# true: N3YC9
# pred: N3YC9
# true: 6AAK
# pred: 6AAK
# true: E6AUD
# pred: E6AUD
# true: CHPSYN
# pred: CHPSYN
# true: H4JNXX
# pred: H4JNXX
# true: 9CHM9
# pred: 9CHM9
# true: 5NMM
# pred: 5NMM
# true: T6TD
# pred: T6TD
# true: 56JH6
# pred: 56JH6
# true: DJPWA
# pred: DJPWA
# true: 3BS6N
# pred: 3BS6N
# true: A4B3
# pred: A4B3
# true: HXVUS
# pred: HXVUS
# true: 6KV34
# pred: 6KV34
# true: 9SEYN
# pred: 9SEYN
# true: EBUMA
# pred: EBUMA
# true: Y5MY
# pred: Y5MY
# true: 339M8M
# pred: 339M8M
# true: P6YYPE
# pred: P6YYPE
# true: 8BEEU
# pred: 8BEEU
# true: UJVWJM
# pred: UJVWJM
# true: BAE5J
# pred: BAE5J
# true: H3CU
# pred: H3CU
# true: 8NN9AH
# pred: 8NN9AH
# true: CEADP
# pred: CEADP
# true: MYSE4
# pred: MYSE4
# true: BN6H4Y
# pred: BN6H4Y
# true: J5TET
# pred: J5TET
# true: YVSB3S
# pred: YVSB3S
# true: JHNCUV
# pred: JHNCUV
# true: 8KU5
# pred: 8KU5
# true: 5XMY
# pred: 5XMY
# true: TW9JEP
# pred: TW9JEP
# true: EP59M
# pred: EP59M
# true: WT5HS
# pred: WT5HS
# true: XH9Y9H
# pred: XH9Y9H
# true: WPD8
# pred: WPD8
# true: 5NN3T
# pred: 5NN3T
# true: PWENY
# pred: PWENY
# true: TCPM5
# pred: TCPM5
# true: 4MC9
# pred: 4MC9
# true: PN45U9
# pred: PN45U9
# true: 8993
# pred: 8993
# true: YJ6MW
# pred: YJ6MW
# true: BYKNN
# pred: BYKNN
# true: KP54W
# pred: KP54W
# true: S9REW
# pred: S9REW
# true: XCDT4
# pred: XCDT4
# true: B4DYC3
# pred: B4DYC3
# true: N859
# pred: N859
# true: X5BYDB
# pred: X5BYDB
# true: HJ53K
# pred: HJ53K
# true: 5WAN4
# pred: 5WAN4
# true: V6T9DH
# pred: V6T9DH
# true: BVD9
# pred: BVD9
# true: WEA5R
# pred: WEA5R
# true: XCPRP
# pred: XCPRP
# true: 5RUK3
# pred: 5RUK3
# true: HEJJE
# pred: HEJJE
# true: U694
# pred: U694
# true: XTSR36
# pred: XTSR36
# true: ENHTJ
# pred: ENHTJ
# true: XNU5DE
# pred: XNU5DE
# true: JP8P
# pred: JP8P
# true: BYTHW4
# pred: BYTHW4
# true: 8WYS9
# pred: 8WYS9
# true: D3MME
# pred: D3MME
# true: RRP8
# pred: RRP8
# true: S5CTB
# pred: S5CTB
# true: 4BAD
# pred: 4BAD
# true: BXCNC
# pred: BXCNC
# true: JK6AW
# pred: JK6AW
# true: WD4K
# pred: WD4K
# true: 9YWT
# pred: 9YWT
# true: X5985C
# pred: X5985C
# true: SB9J
# pred: SB9J
# true: HE6A
# pred: HE6A
# true: DHP5
# pred: DHP5
# true: AUNC
# pred: AUNC
# true: KC89
# pred: KC89
# true: P5TD
# pred: P5TD
# true: XA8R
# pred: XA8R
# true: TV8K5
# pred: TV8K5
# true: 5CKBS
# pred: 5CKBS
# true: RJMC3
# pred: RJMC3
# true: NCH6
# pred: NCH6
# true: MUNB9
# pred: MUNB9
# true: MMTMM
# pred: MMTMM
# true: XK5W
# pred: XK5W
# true: 4CUUW
# pred: 4CUUW
# true: CDN89
# pred: CDN89
# true: E9XC
# pred: E9XC
# true: J6ENM
# pred: J6ENM
# true: EXNPT
# pred: EXNPT
# true: H9SYYY
# pred: H9SYYY
# true: 4T43TT
# pred: 4T43TT
# true: NNJ8TW
# pred: NNJ8TW
# true: XRK6R9
# pred: XRK6R9
# true: 6JEY
# pred: 6JEY
# true: BXBNWB
# pred: BXBNWB
# true: 4HX3
# pred: 4HX3
# true: KDPHPN
# pred: KDPHPN
# true: JWKYV
# pred: JWKYV
# true: C4JD
# pred: C4JD
# true: E9TJA
# pred: E9TJA
# true: V85UP
# pred: V85UP
# true: THPM
# pred: THPM
# true: D3E9J
# pred: D3E9J
# true: RA4X3
# pred: RA4X3
# true: ASHV
# pred: ASHV
# true: 6MUTT
# pred: 6MUTT
# true: D5V5
# pred: D5V5
# true: 6MTU
# pred: 6MTU
# true: RCUYB
# pred: RCUYB
# true: DD4K
# pred: DD4K
# true: 43BJ6
# pred: 43BJ6
# true: Y6VDMJ
# pred: Y6VDMJ
# true: EXAKRN
# pred: EXAKRN
# true: B6KDA
# pred: B6KDA
# true: N5YR
# pred: N5YR
# true: M4M8
# pred: M4M8
# true: M9AP
# pred: M9AP
# true: SKB4
# pred: SKB4
# true: 84UE
# pred: 84UE
# true: EBHY8U
# pred: EBHY8U
# true: KW6XV
# pred: KW6XV
# true: CUPCP3
# pred: CUPCP3
# true: 5Y5B3
# pred: 5Y5B3
# true: CEAKPA
# pred: CEAKPA
# true: JYANNJ
# pred: JYANNJ
# true: Y5KYV
# pred: Y5KYV
# true: YAPCBS
# pred: YAPCBS
# true: ESKU
# pred: ESKU
# true: E3SKA
# pred: E3SKA
# true: EMCS
# pred: EMCS
# true: W89Y4
# pred: W89Y4
# true: P4ER
# pred: P4ER
# true: SXMS6
# pred: SXMS6
# true: 95HK
# pred: 95HK
# true: EBY8N4
# pred: EBY8N4
# true: X536HW
# pred: X536HW
# true: PJ3HXJ
# pred: PJ3HXJ
# true: ED93
# pred: ED93
# true: MH6H
# pred: MH6H
# true: XXD8
# pred: XXD8
# true: YNM4R
# pred: YNM4R
# true: 359HT5
# pred: 359HT5
# true: CB9A
# pred: CB9A
# true: 994AY
# pred: 994AY
# true: PHSX3C
# pred: PHSX3C
# true: VYWM
# pred: VYWM
# true: C5N5
# pred: C5N5
# true: BSX8S
# pred: BSX8S
# true: NSX3
# pred: NSX3
# true: 859W
# pred: 859W
# true: CYJD6
# pred: CYJD6
# true: 4JB45V
# pred: 4JB45V
# true: E3CV
# pred: E3CV
# true: M59HJ5
# pred: M59HJ5
# true: ACMD5
# pred: ACMD5
# true: VMY3D
# pred: VMY3D
# true: 4NBE85
# pred: 4NBE85
# true: 63CU
# pred: 63CU
# true: H6E8
# pred: H6E8
# true: HXE9A
# pred: HXE9A
# true: 54B5
# pred: 54B5
# true: JCDUKH
# pred: JCDUKH
# true: V6YEW
# pred: V6YEW
# true: 9KSY
# pred: 9KSY
# true: VETHV
# pred: VETHV
# true: 4KYWUV
# pred: 4KYWUV
# true: TXVWBE
# pred: TXVWBE
# true: SNTHM
# pred: SNTHM
# true: E6UNVY
# pred: E6UNVY
# true: MSNTA
# pred: MSNTA
# true: V69A
# pred: V69A
# true: YED4
# pred: YED4
# true: RWW63
# pred: RWW63
# true: YNNDN
# pred: YNNDN
# true: Y4N8X
# pred: Y4N8X
# true: 5X88
# pred: 5X88
# true: PYSBD
# pred: PYSBD
# true: 83P9V
# pred: 83P9V
# true: ET46
# pred: ET46
# true: 3C99
# pred: 3C99
# true: HHXDH
# pred: HHXDH
# true: RW9P
# pred: RW9P
# true: X5EBTK
# pred: X5EBTK
# true: C3CP
# pred: C3CP
# true: DNUPW6
# pred: DNUPW6
# true: KCSA48
# pred: KCSA48
# true: 8ENRMX
# pred: 8ENRMX
# true: RP9W
# pred: RP9W
# true: S8X5
# pred: S8X5
# true: AP6S
# pred: AP6S
# true: NMUP
# pred: NMUP
# true: VESP
# pred: VESP
# true: YYEBY
# pred: YYEBY
# true: BVSB
# pred: BVSB
# true: YMDNT9
# pred: YMDNT9
# true: C8XAUJ
# pred: C8XAUJ
# true: H3UT
# pred: H3UT
# true: 3KYY3
# pred: 3KYY3
# true: KX5TT
# pred: KX5TT
# true: AVWA
# pred: AVWA
# true: DT9K
# pred: DT9K
# true: MHPJEP
# pred: MHPJEP
# true: 4XKXKK
# pred: 4XKXKK
# true: UVBB3
# pred: UVBB3
# true: XMERY
# pred: XMERY
# true: H5M3
# pred: H5M3
# true: JA88W3
# pred: JA88W3
# true: YJWHP
# pred: YJWHP
# true: V4AR
# pred: V4AR
# true: ACHEA
# pred: ACHEA
# true: 58PJEK
# pred: 58PJEK
# true: 63WC3V
# pred: 63WC3V
# true: HCV9W
# pred: HCV9W
# true: PS96T
# pred: PS96T
# true: M8NNJ6
# pred: M8NNJ6
# true: KBN8
# pred: KBN8
# true: CAWW4
# pred: CAWW4
# true: C6KP
# pred: C6KP
# true: XW5N9
# pred: XW5N9
# true: 3B838S
# pred: 3B838S
# true: RXDX
# pred: RXDX
# true: 4VAT9
# pred: 4VAT9
# true: 5TX3NC
# pred: 5TX3NC
# true: XBK4W
# pred: XBK4W
# true: J8C8
# pred: J8C8
# true: Y4S3P
# pred: Y4S3P
# true: PT6H
# pred: PT6H
# true: 9C6CE
# pred: 9C6CE
# true: HVHYK
# pred: HVHYK
# true: EB6STV
# pred: EB6STV
# true: 9XNW
# pred: 9XNW
# true: CT3V
# pred: CT3V
# true: ERUS6
# pred: ERUS6
# true: 4EYHEM
# pred: 4EYHEM
# true: ARMWY
# pred: ARMWY
# true: XU96WB
# pred: XU96WB
# true: AB9YR
# pred: AB9YR
# true: VH88P
# pred: VH88P
# true: HP4KUX
# pred: HP4KUX
# true: CXS6A
# pred: CXS6A
# true: 6PD8C
# pred: 6PD8C
# true: 4XP6
# pred: 4XP6
# true: PJY6BA
# pred: PJY6BA
# true: 853V6
# pred: 853V6
# true: 96CU9U
# pred: 96CU9U
# true: 3UDM6A
# pred: 3UDM6A
# true: 98WN
# pred: 98WN
# true: X9V839
# pred: X9V839
# true: WCD4
# pred: WCD4
# true: R3TXTJ
# pred: R3TXTJ
# true: 3XMR
# pred: 3XMR
# true: BRCC
# pred: BRCC
# true: A5CU9
# pred: A5CU9
# true: YTXA
# pred: YTXA
# true: XR5H5U
# pred: XR5H5U
# true: BNX4B
# pred: BNX4B
# true: SUXE
# pred: SUXE
# true: SVDH6D
# pred: SVDH6D
# true: HMHAW
# pred: HMHAW
# true: 469WB
# pred: 469WB
# true: AVMTUU
# pred: AVMTUU
# true: 96U3
# pred: 96U3
# true: 9SSU
# pred: 9SSU
# true: YSAMY
# pred: YSAMY
# true: RSMVT
# pred: RSMVT
# true: UY5B9C
# pred: UY5B9C
# true: 4MYBY
# pred: 4MYBY
# true: R6VS
# pred: R6VS
# true: SRRWSJ
# pred: SRRWSJ
# true: VX3NBX
# pred: VX3NBX
# true: 4UWAC
# pred: 4UWAC
# true: A8BU38
# pred: A8BU38
# true: Y36U
# pred: Y36U
# true: DBN6
# pred: DBN6
# true: DKU445
# pred: DKU445
# true: PR66
# pred: PR66
# true: N8JUX
# pred: N8JUX
# true: AMV5W
# pred: AMV5W
# true: VUB3S3
# pred: VUB3S3
# true: BRPTBM
# pred: BRPTBM
# true: 3PD55
# pred: 3PD55
# true: 6PSN
# pred: 6PSN
# true: Y3J3K
# pred: Y3J3K
# true: SMHJY
# pred: SMHJY
# true: W65Y
# pred: W65Y
# true: MVT3A
# pred: MVT3A
# true: 4WEH3C
# pred: 4WEH3C
# true: NSK8MS
# pred: NSK8MS
# true: 8DEHDT
# pred: 8DEHDT
# true: X66DK
# pred: X66DK
# true: SNCAJK
# pred: SNCAJK
# true: 83Y3A
# pred: 83Y3A
# true: 5BK5D
# pred: 5BK5D
# true: UXPRTP
# pred: UXPRTP
# true: 8RCJBK
# pred: 8RCJBK
# true: 9VYC
# pred: 9VYC
# true: KDKJY
# pred: KDKJY
# true: USMJW
# pred: USMJW
# true: NY85JE
# pred: NY85JE
# true: X6RTW
# pred: X6RTW
# true: DEHJPD
# pred: DEHJPD
# true: 8X5EXK
# pred: 8X5EXK
# true: 9YH38S
# pred: 9YH38S
# true: 8MNCE
# pred: 8MNCE
# true: P8B6
# pred: P8B6
# true: DBKYYA
# pred: DBKYYA
# true: RCCRYW
# pred: RCCRYW
# true: XXWJT8
# pred: XXWJT8
# true: KA4PB
# pred: KA4PB
# true: THNNVJ
# pred: THNNVJ
# true: EKDA4
# pred: EKDA4
# true: HCXPU
# pred: HCXPU
# true: 8JMCE
# pred: 8JMCE
# true: UBY4BS
# pred: UBY4BS
# true: RUUEYB
# pred: RUUEYB
# true: MJR33
# pred: MJR33
# true: NEW5
# pred: NEW5
# true: V9E8T
# pred: V9E8T
# true: 6V8D
# pred: 6V8D
# true: MWMHR
# pred: MWMHR
# true: 6K9JU
# pred: 6K9JU
# true: BMX5K
# pred: BMX5K
# true: 4YNNY
# pred: 4YNNY
# true: W8SB
# pred: W8SB
# true: CTC4
# pred: CTC4
# true: 4M3W5S
# pred: 4M3W5S
# true: MJB34
# pred: MJB34
# true: SP9P
# pred: SP9P
# true: PYXVTP
# pred: PYXVTP
# true: PU6REW
# pred: PU6REW
# true: 9XREK
# pred: 9XREK
# true: 4RUP5
# pred: 4RUP5
# true: 6KPJ
# pred: 6KPJ
# true: W9SUDK
# pred: W9SUDK
# true: TYTS8
# pred: TYTS8
# true: RCAU
# pred: RCAU
# true: S8VT4
# pred: S8VT4
# true: W9R6A
# pred: W9R6A
# true: MUR3
# pred: MUR3
# true: AVWW3
# pred: AVWW3
# true: T53KA5
# pred: T53KA5
# true: YTTH6K
# pred: YTTH6K
# true: 4SUK3
# pred: 4SUK3
# true: 4EUARY
# pred: 4EUARY
# true: AMNUJ
# pred: AMNUJ
# true: 9NR8
# pred: 9NR8
# true: NWSH
# pred: NWSH
# true: U4XT
# pred: U4XT
# true: EJPTM
# pred: EJPTM
# true: 46DW4
# pred: 46DW4
# true: EEWHWM
# pred: EEWHWM
# true: TDDVW
# pred: TDDVW
# true: 53DT
# pred: 53DT
# true: HAENB
# pred: HAENB
# true: PVSNDR
# pred: PVSNDR
# true: 9HUSD3
# pred: 9HUSD3
# true: TXKCAN
# pred: TXKCAN
# true: NJXW
# pred: NJXW
# true: NMH85
# pred: NMH85
# true: RJ5SM
# pred: RJ5SM
# true: 9U358B
# pred: 9U358B
# true: BWW4UY
# pred: BWW4UY
# true: YCXB
# pred: YCXB
# true: CPAD
# pred: CPAD
# true: UVS9S3
# pred: UVS9S3
# true: 9YJHCE
# pred: 9YJHCE
# true: ESNEM
# pred: ESNEM
# true: WEJMPX
# pred: WEJMPX
# true: DPDBA
# pred: DPDBA
# true: JYYC
# pred: JYYC
# true: MBJV65
# pred: MBJV65
# true: BUJR
# pred: BUJR
# true: 9KEDJM
# pred: 9KEDJM
# true: D33UX
# pred: D33UX
# true: 9HR99
# pred: 9HR99
# true: SHJYB
# pred: SHJYB
# true: V8PH
# pred: V8PH
# true: S86UE
# pred: S86UE
# true: 6NJ5Y
# pred: 6NJ5Y
# true: HHPE
# pred: HHPE
# true: BAS86J
# pred: BAS86J
# true: B3X8
# pred: B3X8
# true: 3YRD
# pred: 3YRD
# true: RYUCP
# pred: RYUCP
# true: ECWKJ
# pred: ECWKJ
# true: R9UTR4
# pred: R9UTR4
# true: T5TUW
# pred: T5TUW
# true: 6J9CYM
# pred: 6J9CYM
# true: AXK9M
# pred: AXK9M
# true: UHSV
# pred: UHSV
# true: JJYYN
# pred: JJYYN
# true: D96UKR
# pred: D96UKR
# true: CE4K
# pred: CE4K
# true: EH3U
# pred: EH3U
# true: 6XPK
# pred: 6XPK
# true: V5YXBD
# pred: V5YXBD
# true: RPYKPU
# pred: RPYKPU
# true: MVKJ
# pred: MVKJ
# true: 39DTS6
# pred: 39DTS6
# true: J4SKS
# pred: J4SKS
# true: M6RT
# pred: M6RT
# true: 9KPVNS
# pred: 9KPVNS
# true: E8NJK
# pred: E8NJK
# true: 8NTB
# pred: 8NTB
# true: N55WTX
# pred: N55WTX
# true: R3BJ
# pred: R3BJ
# true: HBY4
# pred: HBY4
# true: BEWRUJ
# pred: BEWRUJ
# true: XB59
# pred: XB59
# true: RST8
# pred: RST8
# true: E6SR
# pred: E6SR
# true: T6E9KP
# pred: T6E9KP
# true: VSXCB
# pred: VSXCB
# true: 5JNC9J
# pred: 5JNC9J
# true: KKDW
# pred: KKDW
# true: 8EJSU
# pred: 8EJSU
# true: 43B333
# pred: 43B333
# true: XWV45
# pred: XWV45
# true: EHV9V3
# pred: EHV9V3
# true: JCMXA
# pred: JCMXA
# true: VCHA
# pred: VCHA
# true: A484MR
# pred: A484MR
# true: YT45MR
# pred: YT45MR
# true: RC48
# pred: RC48
# true: D44VN
# pred: D44VN
# true: 9ETRN
# pred: 9ETRN
# true: ASM9
# pred: ASM9
# true: 33BE
# pred: 33BE
# true: CCPD
# pred: CCPD
# true: MP6KY
# pred: MP6KY
# true: DT4S
# pred: DT4S
# true: 3CXHXE
# pred: 3CXHXE
# true: XWHY
# pred: XWHY
# true: BM8WU
# pred: BM8WU
# true: SDTDS
# pred: SDTDS
# true: JYMC
# pred: JYMC
# true: DYS9Y
# pred: DYS9Y
# true: EEHU9
# pred: EEHU9
# true: C8HK
# pred: C8HK
# true: P3TM
# pred: P3TM
# true: 8WKEJA
# pred: 8WKEJA
# true: 86MA3P
# pred: 86MA3P
# true: PBPC
# pred: PBPC
# true: U8M6E
# pred: U8M6E
# true: 6YKCX
# pred: 6YKCX
# true: PCSKHB
# pred: PCSKHB
# true: XVAVH
# pred: XVAVH
# true: WHWA
# pred: WHWA
# true: VUSU
# pred: VUSU
# true: J6XAVM
# pred: J6XAVM
# true: J5A6
# pred: J5A6
# true: PXVKVW
# pred: PXVKVW
# true: 5P3A
# pred: 5P3A
# true: XPCAX9
# pred: XPCAX9
# true: A4RU8B
# pred: A4RU8B
# true: TWTT9Y
# pred: TWTT9Y
# true: CA39S
# pred: CA39S
# true: SKBSB
# pred: SKBSB
# true: TJB9
# pred: TJB9
# true: R5EKAT
# pred: R5EKAT
# true: EUSYA
# pred: EUSYA
# true: 4MYDH
# pred: 4MYDH
# true: 9WSJ
# pred: 9WSJ
# true: YPDJ
# pred: YPDJ
# true: 999U
# pred: 999U
# true: XBN63
# pred: XBN63
# true: D5XY45
# pred: D5XY45
# true: UDHB
# pred: UDHB
# true: HJPK
# pred: HJPK
# true: VDPK
# pred: VDPK
# true: 4SS3
# pred: 4SS3
# true: 3TK9K8
# pred: 3TK9K8
# true: EN63
# pred: EN63
# true: JTEV
# pred: JTEV
# true: P9SYX
# pred: P9SYX
# true: NBA6PT
# pred: NBA6PT
# true: W3S36M
# pred: W3S36M
# true: YMBN9
# pred: YMBN9
# true: NBSJK
# pred: NBSJK
# true: 5TT3CE
# pred: 5TT3CE
# true: YX59
# pred: YX59
# true: NKTH
# pred: NKTH
# true: YMEJJV
# pred: YMEJJV
# true: XBS9M9
# pred: XBS9M9
# true: WJJ45A
# pred: WJJ45A
# true: PKTS
# pred: PKTS
# true: KVXM6P
# pred: KVXM6P
# true: HTRDMD
# pred: HTRDMD
# true: K4U4T
# pred: K4U4T
# true: JR4YB
# pred: JR4YB
# true: VXNXV
# pred: VXNXV
# true: 6H5AK
# pred: 6H5AK
# true: 46TB
# pred: 46TB
# true: 656ET3
# pred: 656ET3
# true: EJUWAY
# pred: EJUWAY
# true: 58YA8
# pred: 58YA8
# true: 3TV6H3
# pred: 3TV6H3
# true: WX6J4
# pred: WX6J4
# true: 566UW8
# pred: 566UW8
# true: 35D4JA
# pred: 35D4JA
# true: CY5R
# pred: CY5R
# true: MYTD
# pred: MYTD
# true: VWWAA
# pred: VWWAA
# true: A6UPV
# pred: A6UPV
# true: V9WRS
# pred: V9WRS
# true: EMV6JP
# pred: EMV6JP
# true: MSEY
# pred: MSEY
# true: NKAW
# pred: NKAW
# true: JXAY
# pred: JXAY
# true: P4SSY
# pred: P4SSY
# true: E89DRJ
# pred: E89DRJ
# true: WTCHB
# pred: WTCHB
# true: PDP4
# pred: PDP4
# true: K55CJ
# pred: K55CJ
# true: STY4
# pred: STY4
# true: T5YR
# pred: T5YR
# true: 3NXR4T
# pred: 3NXR4T
# true: KJRXCT
# pred: KJRXCT
# true: WCUMS
# pred: WCUMS
# true: EK4RVH
# pred: EK4RVH
# true: 4VMHW
# pred: 4VMHW
# true: AUUPPT
# pred: AUUPPT
# true: SU34K
# pred: SU34K
# true: 3RCNW4
# pred: 3RCNW4
# true: 4RTB6S
# pred: 4RTB6S
# true: UMXK
# pred: UMXK
# true: 3JCC
# pred: 3JCC
# true: 98Y5R5
# pred: 98Y5R5
# true: PTUBSX
# pred: PTUBSX
# true: HSSS
# pred: HSSS
# true: TM85TW
# pred: TM85TW
# true: B64BK
# pred: B64BK
# true: B4E8
# pred: B4E8
# true: 6RPY
# pred: 6RPY
# true: EVWE
# pred: EVWE
# true: CSBT9E
# pred: CSBT9E
# true: HBEXX
# pred: HBEXX
# true: MAW3
# pred: MAW3
# true: Y95U3Y
# pred: Y95U3Y
# true: C4DM
# pred: C4DM
# true: KEBA
# pred: KEBA
# true: TAT6VW
# pred: TAT6VW
# true: K9C5DA
# pred: K9C5DA
# true: BSAB
# pred: BSAB
# true: BRJNCV
# pred: BRJNCV
# true: 9HDSW
# pred: 9HDSW
# true: 4H3BK
# pred: 4H3BK
# true: M9UN
# pred: M9UN
# true: 4SY9P6
# pred: 4SY9P6
# true: NYVBP
# pred: NYVBP
# true: PEAK5
# pred: PEAK5
# true: RHY3
# pred: RHY3
# true: KPXC5T
# pred: KPXC5T
# true: X5RK
# pred: X5RK
# true: 639ARM
# pred: 639ARM
# true: N4NX4X
# pred: N4NX4X
# true: XY5T
# pred: XY5T
# true: 3NKS
# pred: 3NKS
# true: UV4E
# pred: UV4E
# true: XM6S86
# pred: XM6S86
# true: T83V
# pred: T83V
# true: 6CAXS
# pred: 6CAXS
# true: YXJV
# pred: YXJV
# true: USJ8NS
# pred: USJ8NS
# true: W6NK
# pred: W6NK
# true: SKUJ
# pred: SKUJ
# true: WXMX3J
# pred: WXMX3J
# true: X954DV
# pred: X954DV
# true: C3WK
# pred: C3WK
# true: JRM5
# pred: JRM5
# true: EE8X
# pred: EE8X
# true: TJ6XPD
# pred: TJ6XPD
# true: 3DRXP
# pred: 3DRXP
# true: 8XCRX
# pred: 8XCRX
# true: C866
# pred: C866
# true: NUXHH
# pred: NUXHH
# true: H6J9CY
# pred: H6J9CY
# true: HKC3TH
# pred: HKC3TH
# true: VADRW
# pred: VADRW
# true: 6SMA
# pred: 6SMA
# true: DC5Y
# pred: DC5Y
# true: YKTBK
# pred: YKTBK
# true: XS6U6
# pred: XS6U6
# true: A8N39
# pred: A8N39
# true: KTVC
# pred: KTVC
# true: 5EP6
# pred: 5EP6
# true: VPCB58
# pred: VPCB58
# true: WA6T8
# pred: WA6T8
# true: 49W3C
# pred: 49W3C
# true: TE5C8
# pred: TE5C8
# true: UYNC9S
# pred: UYNC9S
# true: EEEW
# pred: EEEW
# true: WR44H
# pred: WR44H
# true: CH8V
# pred: CH8V
# true: XYYA5W
# pred: XYYA5W
# true: MK6T
# pred: MK6T
# true: S33K
# pred: S33K
# true: HWYW4
# pred: HWYW4
# true: N6D4BP
# pred: N6D4BP
# true: T3XB
# pred: T3XB
# true: B499U
# pred: B499U
# true: 96E9P
# pred: 96E9P
# true: P45K4W
# pred: P45K4W
# true: KBRXC
# pred: KBRXC
# true: 5BH9N
# pred: 5BH9N
# true: 9ANUV
# pred: 9ANUV
# true: EKAE4
# pred: EKAE4
# true: 3BYTB
# pred: 3BYTB
# true: BBTP6
# pred: BBTP6
# true: Y5DV
# pred: Y5DV
# true: 3E9UM
# pred: 3E9UM
# true: K65YVM
# pred: K65YVM
# true: MUYSHM
# pred: MUYSHM
# true: TDTV
# pred: TDTV
# true: 5M4UXE
# pred: 5M4UXE
# true: MY6PEW
# pred: MY6PEW
# true: ATUW
# pred: ATUW
# true: R8JUU
# pred: R8JUU
# true: SUHB9S
# pred: SUHB9S
# true: 6H5B
# pred: 6H5B
# true: WSXW
# pred: WSXW
# true: W4RWW
# pred: W4RWW
# true: 6HXY
# pred: 6HXY
# true: Y4D5
# pred: Y4D5
# true: KK5SXC
# pred: KK5SXC
# true: P5AW
# pred: P5AW
# true: HHSPU
# pred: HHSPU
# true: 4UU64
# pred: 4UU64
# true: KYUUM
# pred: KYUUM
# true: 64K8
# pred: 64K8
# true: SE9HVY
# pred: SE9HVY
# true: SAN6
# pred: SAN6
# true: C5HEK
# pred: C5HEK
# true: B885
# pred: B885
# true: HNVAT
# pred: HNVAT
# true: CH8JR
# pred: CH8JR
# true: BBES9B
# pred: BBES9B
# true: U5PNMW
# pred: U5PNMW
# true: PBV5
# pred: PBV5
# true: MKCWAA
# pred: MKCWAA
# true: 3C8N
# pred: 3C8N
# true: TAN99R
# pred: TAN99R
# true: W9UR
# pred: W9UR
# true: CSXSBJ
# pred: CSXSBJ
# true: URU3XV
# pred: URU3XV
# true: 96645E
# pred: 96645E
# true: 86HW
# pred: 86HW
# true: AXEJV3
# pred: AXEJV3
# true: NENE
# pred: NENE
# true: 6DEWA6
# pred: 6DEWA6
# true: NAUH
# pred: NAUH
# true: VNBNMH
# pred: VNBNMH
# true: YBDB6H
# pred: YBDB6H
# true: 8WVA
# pred: 8WVA
# true: UEJNB
# pred: UEJNB
# true: 33D5JN
# pred: 33D5JN
# true: 9RYE
# pred: 9RYE
# true: BB3J
# pred: BB3J
# true: PB8U
# pred: PB8U
# true: KUWPT8
# pred: KUWPT8
# true: 3ED9
# pred: 3ED9
# true: 6WHC
# pred: 6WHC
# true: VKBBP9
# pred: VKBBP9
# true: M6PWTE
# pred: M6PWTE
# true: AYXD
# pred: AYXD
# true: M3J6VW
# pred: M3J6VW
# true: JCTERE
# pred: JCTERE
# true: EADCT
# pred: EADCT
# true: 3EE8HA
# pred: 3EE8HA
# true: YH8R
# pred: YH8R
# true: 8DYY5K
# pred: 8DYY5K
# true: 8RBT
# pred: 8RBT
# true: 4ADVS
# pred: 4ADVS
# true: SPXC
# pred: SPXC
# true: M386W
# pred: M386W
# true: WPH649
# pred: WPH649
# true: U8DH
# pred: U8DH
# true: Y3V9C
# pred: Y3V9C
# true: EWSBR
# pred: EWSBR
# true: TSSS
# pred: TSSS
# true: SUHH6D
# pred: SUHH6D
# true: V3SD
# pred: V3SD
# true: 4P8X
# pred: 4P8X
# true: 5C3U
# pred: 5C3U
# true: WD9HU
# pred: WD9HU
# true: JMUY
# pred: JMUY
# true: Y9WYW9
# pred: Y9WYW9
# true: AC6MSW
# pred: AC6MSW
# true: CUECY
# pred: CUECY
# true: JWSHWS
# pred: JWSHWS
# true: T3NK
# pred: T3NK
# true: T5UMU
# pred: T5UMU
# true: HTEPNY
# pred: HTEPNY
# true: W8JA
# pred: W8JA
# true: 8AATCB
# pred: 8AATCB
# true: UDWC
# pred: UDWC
# true: 4XX4
# pred: 4XX4
# true: EHV6
# pred: EHV6
# true: SE8XHJ
# pred: SE8XHJ
# true: M8US
# pred: M8US
# true: NHJ6UJ
# pred: NHJ6UJ
# true: MNPW
# pred: MNPW
# true: V5VH
# pred: V5VH
# true: JN8R49
# pred: JN8R49
# true: TCRMAB
# pred: TCRMAB
# true: D3P6T9
# pred: D3P6T9
# true: D4M65
# pred: D4M65
# true: 934PA
# pred: 934PA
# true: 95KXYS
# pred: 95KXYS
# true: 5ASSKC
# pred: 5ASSKC
# true: UDUM
# pred: UDUM
# true: WYBV
# pred: WYBV
# true: K4B8AV
# pred: K4B8AV
# true: BB33
# pred: BB33
# true: SECV59
# pred: SECV59
# true: Y9T6M
# pred: Y9T6M
# true: ASC5
# pred: ASC5
# true: UAVPX
# pred: UAVPX
# true: RDVWA5
# pred: RDVWA5
# true: 3AWBMB
# pred: 3AWBMB
# true: STWK
# pred: STWK
# true: 8BTWCV
# pred: 8BTWCV
# true: T9WN3
# pred: T9WN3
# true: RCHH4
# pred: RCHH4
# true: N4YK
# pred: N4YK
# true: PNUNH
# pred: PNUNH
# true: EHKM
# pred: EHKM
# true: AS9J4K
# pred: AS9J4K
# true: B8TE9
# pred: B8TE9
# true: TR55
# pred: TR55
# true: UY43U
# pred: UY43U
# true: RW5AD
# pred: RW5AD
# true: YEV5
# pred: YEV5
# true: BNCVX5
# pred: BNCVX5
# true: AXTD
# pred: AXTD
# true: 3H3RWP
# pred: 3H3RWP
# true: K6XMYK
# pred: K6XMYK
# true: TPVXP
# pred: TPVXP
# true: YPHUKD
# pred: YPHUKD
# true: WC8DX
# pred: WC8DX
# true: 6JSEDS
# pred: 6JSEDS
# true: WD4EVS
# pred: WD4EVS
# true: EETXE4
# pred: EETXE4
# true: 99H4V9
# pred: 99H4V9
# true: 9P4XSY
# pred: 9P4XSY
# true: KUTV9
# pred: KUTV9
# true: VBSX
# pred: VBSX
# true: VS3N
# pred: VS3N
# true: NBXM
# pred: NBXM
# true: HSUX9
# pred: HSUX9
# true: A3NVRD
# pred: A3NVRD
# true: TVPCT5
# pred: TVPCT5
# true: 6HHY
# pred: 6HHY
# true: HKKJ9
# pred: HKKJ9
# true: YC99E
# pred: YC99E
# true: CJDAMN
# pred: CJDAMN
# true: YVU8M
# pred: YVU8M
# true: MBVHE
# pred: MBVHE
# true: B5UJW
# pred: B5UJW
# true: KEMCX8
# pred: KEMCX8
# true: 5E4KSJ
# pred: 5E4KSJ
# true: VN9UR
# pred: VN9UR
# true: JURA4
# pred: JURA4
# true: 4484
# pred: 4484
# true: TXJW
# pred: TXJW
# true: B9A5
# pred: B9A5
# true: ERXPR
# pred: ERXPR
# true: 9C5MUN
# pred: 9C5MUN
# true: 4BJK5
# pred: 4BJK5
# true: X9WY9
# pred: X9WY9
# true: EPYKN
# pred: EPYKN
# true: VUMY
# pred: VUMY
# true: BRUH
# pred: BRUH
# true: UHJV
# pred: UHJV
# true: MHM5D
# pred: MHM5D
# true: VERYP
# pred: VERYP
# true: ET3NV5
# pred: ET3NV5
# true: KCY8K
# pred: KCY8K
# true: 5PP3P
# pred: 5PP3P
# true: C456
# pred: C456
# true: 3HDEM
# pred: 3HDEM
# true: A8MYN
# pred: A8MYN
# true: 9DUYM8
# pred: 9DUYM8
# true: JX9BK
# pred: JX9BK
# true: JR5P
# pred: JR5P
# true: HRXE
# pred: HRXE
# true: Y48K
# pred: Y48K
# true: 5R9STK
# pred: 5R9STK
# true: W4WHRD
# pred: W4WHRD
# true: TEVW8
# pred: TEVW8
# true: PW59
# pred: PW59
# true: 64JV
# pred: 64JV
# true: NWMMCD
# pred: NWMMCD
# true: 8JBD46
# pred: 8JBD46
# true: 8H4C94
# pred: 8H4C94
# true: 3E8RU9
# pred: 3E8RU9
# true: V3SN
# pred: V3SN
# true: KNNKDX
# pred: KNNKDX
# true: C59PH
# pred: C59PH
# true: BVDT
# pred: BVDT
# true: 889M
# pred: 889M
# true: 8JRNW
# pred: 8JRNW
# true: DX55C8
# pred: DX55C8
# true: BXEUR
# pred: BXEUR
# true: KCMPR
# pred: KCMPR
# true: BPA9AW
# pred: BPA9AW
# true: X4U68
# pred: X4U68
# true: 6YRV
# pred: 6YRV
# true: HSDMK
# pred: HSDMK
# true: 6N6VWY
# pred: 6N6VWY
# true: J5Y8
# pred: J5Y8
# true: YMCVU5
# pred: YMCVU5
# true: BKDA
# pred: BKDA
# true: X4UTD
# pred: X4UTD
# true: 3BEB
# pred: 3BEB
# true: RXXEWS
# pred: RXXEWS
# true: Y44VH
# pred: Y44VH
# true: MW95VC
# pred: MW95VC
# true: D534
# pred: D534
# true: JMMP
# pred: JMMP
# true: 8CA9BS
# pred: 8CA9BS
# true: 5BY8
# pred: 5BY8
# true: TBEWU
# pred: TBEWU
# true: KCDA
# pred: KCDA
# true: JTWD8
# pred: JTWD8
# true: AC6VST
# pred: AC6VST
# true: E9RRV
# pred: E9RRV
# true: VTSTNE
# pred: VTSTNE
# true: 8J8W
# pred: 8J8W
# true: 5NB9D
# pred: 5NB9D
# true: W4NP
# pred: W4NP
# true: T96YCM
# pred: T96YCM
# true: 3E4R8D
# pred: 3E4R8D
# true: W9SSH
# pred: W9SSH
# true: 3YYAJW
# pred: 3YYAJW
# true: 856AK
# pred: 856AK
# true: C4ND
# pred: C4ND
# true: YM8PXB
# pred: YM8PXB
# true: MVCW
# pred: MVCW
# true: AXJ5KM
# pred: AXJ5KM
# true: B5M3
# pred: B5M3
# true: KPRHE
# pred: KPRHE
# true: JXYVB9
# pred: JXYVB9
# true: EJE5J3
# pred: EJE5J3
# true: 4SR6YV
# pred: 4SR6YV
# true: VUMA
# pred: VUMA
# true: 4YDNA
# pred: 4YDNA
# true: YET3
# pred: YET3
# true: SRMX
# pred: SRMX
# true: 3JXR5
# pred: 3JXR5
# true: CWV48T
# pred: CWV48T
# true: BHTN
# pred: BHTN
# true: P46W5
# pred: P46W5
# true: SHUS
# pred: SHUS
# true: XYTNX3
# pred: XYTNX3
# true: EB6XP
# pred: EB6XP
# true: VA6P3D
# pred: VA6P3D
# true: P3U9V8
# pred: P3U9V8
# true: USNM9
# pred: USNM9
# true: SV96
# pred: SV96
# true: 3YKE4
# pred: 3YKE4
# true: N6JD
# pred: N6JD
# true: WAD6AK
# pred: WAD6AK
# true: WK69H
# pred: WK69H
# true: B83X3B
# pred: B83X3B
# true: AYC86V
# pred: AYC86V
# true: CCE5
# pred: CCE5
# true: EB8CKN
# pred: EB8CKN
# true: K6MTM
# pred: K6MTM
# true: EYMM4
# pred: EYMM4
# true: 94YRU4
# pred: 94YRU4
# true: DBHJK
# pred: DBHJK
# true: R58W4
# pred: R58W4
# true: BV6C
# pred: BV6C
# true: AV4AR
# pred: AV4AR
# true: YUU3
# pred: YUU3
# true: CAXJDV
# pred: CAXJDV
# true: HW6SAK
# pred: HW6SAK
# true: VMB4YW
# pred: VMB4YW
# true: EVU6P
# pred: EVU6P
# true: H3EW
# pred: H3EW
# true: D4MSUX
# pred: D4MSUX
# true: A68DTN
# pred: A68DTN
# true: 6DSKP
# pred: 6DSKP
# true: KASKTP
# pred: KASKTP
# true: 6WJX
# pred: 6WJX
# true: 9PAR
# pred: 9PAR
# true: C8NV34
# pred: C8NV34
# true: U6E6
# pred: U6E6
# true: BUTD
# pred: BUTD
# true: AC3PE
# pred: AC3PE
# true: 36UMU
# pred: 36UMU
# true: 4DWEX6
# pred: 4DWEX6
# true: HW8KW
# pred: HW8KW
# true: BRT46J
# pred: BRT46J
# true: 5C8XE
# pred: 5C8XE
# true: DX4JUY
# pred: DX4JUY
# true: PHMRB
# pred: PHMRB
# true: B63S
# pred: B63S
# true: WKJN
# pred: WKJN
# true: NPX9
# pred: NPX9
# true: 5SAD
# pred: 5SAD
# true: 5MWVD
# pred: 5MWVD
# true: EJ6HX
# pred: EJ6HX
# true: C5VN
# pred: C5VN
# true: 6H3R4R
# pred: 6H3R4R
# true: 8R3KE
# pred: 8R3KE
# true: 9J84
# pred: 9J84
# true: HXBE3
# pred: HXBE3
# true: ACKM
# pred: ACKM
# true: PP39X9
# pred: PP39X9
# true: 5DDBP
# pred: 5DDBP
# true: DHHB
# pred: DHHB
# true: PNCH9E
# pred: PNCH9E
# true: PV3BN
# pred: PV3BN
# true: A88ATD
# pred: A88ATD
# true: 4WX5B
# pred: 4WX5B
# true: 5S8Y
# pred: 5S8Y
# true: NMRPV
# pred: NMRPV
# true: CTWHDX
# pred: CTWHDX
# true: HJKR
# pred: HJKR
# true: 98TJ
# pred: 98TJ
# true: DVXE
# pred: DVXE
# true: 9VP8JM
# pred: 9VP8JM
# true: T4RJNH
# pred: T4RJNH
# true: 5SJPH
# pred: 5SJPH
# true: UXBREW
# pred: UXBREW
# true: BCX4N5
# pred: BCX4N5
# true: WTCD
# pred: WTCD
# true: B4VA
# pred: B4VA
# true: KWC4N
# pred: KWC4N
# true: 3W3HW
# pred: 3W3HW
# true: ECDD
# pred: ECDD
# true: AYJH
# pred: AYJH
# true: 3MVA
# pred: 3MVA
# true: 6CSUCE
# pred: 6CSUCE
# true: SCBEP
# pred: SCBEP
# true: NB6WRT
# pred: NB6WRT
# true: BD5B
# pred: BD5B
# true: W3SSC
# pred: W3SSC
# true: 8UCEH
# pred: 8UCEH
# true: M4E4R
# pred: M4E4R
# true: 856MM
# pred: 856MM
# true: 6KS6B8
# pred: 6KS6B8
# true: 686W
# pred: 686W
# true: H4DRE8
# pred: H4DRE8
# true: N9YDRA
# pred: N9YDRA
# true: AX53K
# pred: AX53K
# true: NWW3
# pred: NWW3
# true: VDBH
# pred: VDBH
# true: SVBDV
# pred: SVBDV
# true: KDXXPX
# pred: KDXXPX
# true: SR9V
# pred: SR9V
# true: SKSKD
# pred: SKSKD
# true: XWC6TU
# pred: XWC6TU
# true: Y863
# pred: Y863
# true: EXM6
# pred: EXM6
# true: SW3RB
# pred: SW3RB
# true: TBE4H
# pred: TBE4H
# true: YDYCUM
# pred: YDYCUM
# true: KXC8
# pred: KXC8
# true: 3PP8D
# pred: 3PP8D
# true: 5RNT
# pred: 5RNT
# true: SMDUB
# pred: SMDUB
# true: MTTE
# pred: MTTE
# true: CJED5
# pred: CJED5
# true: SNMA
# pred: SNMA
# true: RKPV
# pred: RKPV
# true: TC4J
# pred: TC4J
# true: RX3A9V
# pred: RX3A9V
# true: Y8TC5U
# pred: Y8TC5U
# true: RX9HM
# pred: RX9HM
# true: 4XCEM
# pred: 4XCEM
# true: A4R5
# pred: A4R5
# true: 33N84C
# pred: 33N84C
# true: VJSEHX
# pred: VJSEHX
# true: 9CAX
# pred: 9CAX
# true: DB83
# pred: DB83
# true: E6PSB
# pred: E6PSB
# true: 8Y96
# pred: 8Y96
# true: 9KPEJ
# pred: 9KPEJ
# true: K5CN
# pred: K5CN
# true: MEHXP4
# pred: MEHXP4
# true: XXEA8K
# pred: XXEA8K
# true: HMJTB
# pred: HMJTB
# true: YKUV
# pred: YKUV
# true: U3BPS
# pred: U3BPS
# true: DHPH8
# pred: DHPH8
# true: YVXP5
# pred: YVXP5
# true: EKSTHD
# pred: EKSTHD
# true: CN5SN
# pred: CN5SN
# true: E46CH
# pred: E46CH
# true: 8HDV
# pred: 8HDV
# true: DCAP
# pred: DCAP
# true: V3W9VK
# pred: V3W9VK
# true: RTAVY
# pred: RTAVY
# true: W5XUC
# pred: W5XUC
# true: 6WDJ
# pred: 6WDJ
# true: 9AVUPA
# pred: 9AVUPA
# true: 3AACB4
# pred: 3AACB4
# true: CS8VWM
# pred: CS8VWM
# true: HEPY
# pred: HEPY
# true: S5BNB
# pred: S5BNB
# true: 9RUKX
# pred: 9RUKX
# true: DAD68E
# pred: DAD68E
# true: PVCSYY
# pred: PVCSYY
# true: 8WUHA
# pred: 8WUHA
# true: JKYHK
# pred: JKYHK
# true: A4JM
# pred: A4JM
# true: PPVK63
# pred: PPVK63
# true: UEP668
# pred: UEP668
# true: E6SADS
# pred: E6SADS
# true: CDUURR
# pred: CDUURR
# true: WSKU
# pred: WSKU
# true: W45W34
# pred: W45W34
# true: 3JJK
# pred: 3JJK
# true: BWXTDM
# pred: BWXTDM
# true: 6MA9K
# pred: 6MA9K
# true: EYAN
# pred: EYAN
# true: DBSS
# pred: DBSS
# true: H95VB
# pred: H95VB
# true: R8SBN
# pred: R8SBN
# true: YSVW
# pred: YSVW
# true: RYABDN
# pred: RYABDN
# true: U9PPW
# pred: U9PPW
# true: 53EV
# pred: 53EV
# true: HW99
# pred: HW99
# true: U9HKU
# pred: U9HKU
# true: 9YN3SR
# pred: 9YN3SR
# true: UB4AY
# pred: UB4AY
# true: UWPB
# pred: UWPB
# true: AKJ66
# pred: AKJ66
# true: NDJKM5
# pred: NDJKM5
# true: BP3BB
# pred: BP3BB
# true: V8U5
# pred: V8U5
# true: KAHMPN
# pred: KAHMPN
# true: 6KC3NR
# pred: 6KC3NR
# true: SHUNXT
# pred: SHUNXT
# true: XEM3
# pred: XEM3
# true: EUA6J
# pred: EUA6J
# true: 9SM5EA
# pred: 9SM5EA
# true: XAXD4
# pred: XAXD4
# true: 8MTT
# pred: 8MTT
# true: 8AU3EK
# pred: 8AU3EK
# true: ADVAU
# pred: ADVAU
# true: BSEB9U
# pred: BSEB9U
# true: 6Y38
# pred: 6Y38
# true: YB68
# pred: YB68
# true: PYP48
# pred: PYP48
# true: MCHTA
# pred: MCHTA
# true: EX4T
# pred: EX4T
# true: TUA5M
# pred: TUA5M
# true: TJDUE
# pred: TJDUE
# true: 5KS9
# pred: 5KS9
# true: TWKSS9
# pred: TWKSS9
# true: SKUB
# pred: SKUB
# true: 3VUVXW
# pred: 3VUVXW
# true: CM3D
# pred: CM3D
# true: UN49B
# pred: UN49B
# true: CMV6
# pred: CMV6
# true: AYTD
# pred: AYTD
# true: 8D3PU
# pred: 8D3PU
# true: CRPH5
# pred: CRPH5
# true: WK9N6
# pred: WK9N6
# true: JEJE
# pred: JEJE
# true: YKCW8
# pred: YKCW8
# true: YCRCCJ
# pred: YCRCCJ
# true: DXYYV
# pred: DXYYV
# true: NMC9R
# pred: NMC9R
# true: XSJS58
# pred: XSJS58
# true: YJSJ
# pred: YJSJ
# true: UNPV
# pred: UNPV
# true: BNXUVK
# pred: BNXUVK
# true: C33MA
# pred: C33MA
# true: PCX3
# pred: PCX3
# true: BE49RB
# pred: BE49RB
# true: C8DTSE
# pred: C8DTSE
# true: NMPUB
# pred: NMPUB
# true: H9ND
# pred: H9ND
# true: N5KR5R
# pred: N5KR5R
# true: MJKC5
# pred: MJKC5
# true: HACX
# pred: HACX
# true: XVPVT
# pred: XVPVT
# true: MSPHPN
# pred: MSPHPN
# true: X6H5
# pred: X6H5
# true: MCTA
# pred: MCTA
# true: JNTUUJ
# pred: JNTUUJ
# true: CRDYY
# pred: CRDYY
# true: VWUVWY
# pred: VWUVWY
# true: PKU8HX
# pred: PKU8HX
# true: B8JDMA
# pred: B8JDMA
# true: 8NRC5D
# pred: 8NRC5D
# true: D984E
# pred: D984E
# true: RXJP8
# pred: RXJP8
# true: YYE3SS
# pred: YYE3SS
# true: NESS9D
# pred: NESS9D
# true: 83TW4P
# pred: 83TW4P
# true: R396
# pred: R396
# true: HRHDJA
# pred: HRHDJA
# true: YDSYNP
# pred: YDSYNP
# true: J49TXR
# pred: J49TXR
# true: EVUR
# pred: EVUR
# true: KKDJ
# pred: KKDJ
# true: MH9TDN
# pred: MH9TDN
# true: HR89YD
# pred: HR89YD
# true: RY9R5
# pred: RY9R5
# true: M48DDJ
# pred: M48DDJ
# true: A6TC9
# pred: A6TC9
# true: PCANY
# pred: PCANY
# true: D3X5X6
# pred: D3X5X6
# true: YXV8Y
# pred: YXV8Y
# true: NTH5
# pred: NTH5
# true: 69USN
# pred: 69USN
# true: 8N5TK
# pred: 8N5TK
# true: 9C9CUA
# pred: 9C9CUA
# true: CJDH4U
# pred: CJDH4U
# true: P9RN
# pred: P9RN
# true: AY5R
# pred: AY5R
# true: WEHK9
# pred: WEHK9
# true: YTVA5
# pred: YTVA5
# true: 69HE5
# pred: 69HE5
# true: RAU4H
# pred: RAU4H
# true: NJT4
# pred: NJT4
# true: V9E4SX
# pred: V9E4SX
# true: MM4H
# pred: MM4H
# true: WV94
# pred: WV94
# true: N54VNH
# pred: N54VNH
# true: 4DETV4
# pred: 4DETV4
# true: A93D
# pred: A93D
# true: JXJMMC
# pred: JXJMMC
# true: WV3AJ
# pred: WV3AJ
# true: YRY8
# pred: YRY8
# true: S99VMT
# pred: S99VMT
# true: V3Y3SW
# pred: V3Y3SW
# true: KKAAX
# pred: KKAAX
# true: ADDV5U
# pred: ADDV5U
# true: HYNHXT
# pred: HYNHXT
# true: TBJ4
# pred: TBJ4
# true: A3E6
# pred: A3E6
# true: 8TCS
# pred: 8TCS
# true: T3XT
# pred: T3XT
# true: 5UC6
# pred: 5UC6
# true: UC4AJJ
# pred: UC4AJJ
# true: 6YSV8
# pred: 6YSV8
# true: RXH98Y
# pred: RXH98Y
# true: TU9S
# pred: TU9S
# true: TEVDR
# pred: TEVDR
# true: DVNVSC
# pred: DVNVSC
# true: NUST
# pred: NUST
# true: V55YH
# pred: V55YH
# true: WSD8D
# pred: WSD8D
# true: 8HDSH
# pred: 8HDSH
# true: M8X64
# pred: M8X64
# true: U34B
# pred: U34B
# true: 44D3T
# pred: 44D3T
# true: HP4V
# pred: HP4V
# true: S36N
# pred: S36N
# true: W4SH4H
# pred: W4SH4H
# true: 6UJ4M3
# pred: 6UJ4M3
# true: SCBK
# pred: SCBK
# true: 8NDD
# pred: 8NDD
# true: TEDMP
# pred: TEDMP
# true: AHHRB
# pred: AHHRB
# true: XJ3NMC
# pred: XJ3NMC
# true: MMC4
# pred: MMC4
# true: VD9BXA
# pred: VD9BXA
# true: ANVRHP
# pred: ANVRHP
# true: SAKP
# pred: SAKP
# true: MYXCJK
# pred: MYXCJK
# true: D6VWP
# pred: D6VWP
# true: NTVW
# pred: NTVW
# true: 69VPXE
# pred: 69VPXE
# true: 68D4VU
# pred: 68D4VU
# true: 5BYSVA
# pred: 5BYSVA
# true: 3D4ANM
# pred: 3D4ANM
# true: 54E8Y3
# pred: 54E8Y3
# true: 3PCEUC
# pred: 3PCEUC
# true: XEXA
# pred: XEXA
# true: BRH66
# pred: BRH66
# true: PJ8MP
# pred: PJ8MP
# true: U6Y8
# pred: U6Y8
# true: PWRU
# pred: PWRU
# true: 4ERDAT
# pred: 4ERDAT
# true: 4EAT
# pred: 4EAT
# true: XJENH6
# pred: XJENH6
# true: 4Y6U
# pred: 4Y6U
# true: XTEP3
# pred: XTEP3
# true: AMMA
# pred: AMMA
# true: 3BSMS
# pred: 3BSMS
# true: HKNBV
# pred: HKNBV
# true: Y8WUP
# pred: Y8WUP
# true: W3MURS
# pred: W3MURS
# true: PMT4
# pred: PMT4
# true: YCAMA
# pred: YCAMA
# true: 9PTYT
# pred: 9PTYT
# true: UVTA
# pred: UVTA
# true: TXKU
# pred: TXKU
# true: T6M9Y
# pred: T6M9Y
# true: 6M9KMX
# pred: 6M9KMX
# true: HR46A6
# pred: HR46A6
# true: HE3B3
# pred: HE3B3
# true: C4VDEV
# pred: C4VDEV
# true: SEU5KA
# pred: SEU5KA
# true: DECCJW
# pred: DECCJW
# true: MBA943
# pred: MBA943
# true: DX4A6
# pred: DX4A6
# true: CDPM
# pred: CDPM
# true: J4V6DS
# pred: J4V6DS
# true: K6NJSK
# pred: K6NJSK
# true: M8VKB
# pred: M8VKB
# true: BUNM
# pred: BUNM
# true: B49N
# pred: B49N
# true: TYDU
# pred: TYDU
# true: AY6SH
# pred: AY6SH
# true: HTB6
# pred: HTB6
# true: ETWPR9
# pred: ETWPR9
# true: APBNSE
# pred: APBNSE
# true: NWDA5T
# pred: NWDA5T
# true: 59CASE
# pred: 59CASE
# true: E6J84K
# pred: E6J84K
# true: MHXCH
# pred: MHXCH
# true: AW99
# pred: AW99
# true: C9JD4
# pred: C9JD4
# true: JMXHX
# pred: JMXHX
# true: TTMXNX
# pred: TTMXNX
# true: PS9A
# pred: PS9A
# true: SHREH
# pred: SHREH
# true: VJH343
# pred: VJH343
# true: 6MDWT3
# pred: 6MDWT3
# true: XYU4
# pred: XYU4
# true: XMV6M
# pred: XMV6M
# true: 8Y6EDM
# pred: 8Y6EDM
# true: VXSSBP
# pred: VXSSBP
# true: NCSA5V
# pred: NCSA5V
# true: UKURJ
# pred: UKURJ
# true: CP5WDA
# pred: CP5WDA
# true: JS888
# pred: JS888
# true: 5JU4D
# pred: 5JU4D
# true: S96YDS
# pred: S96YDS
# true: XA6YU
# pred: XA6YU
# true: SKAH
# pred: SKAH
# true: NRC5EW
# pred: NRC5EW
# true: RYEY
# pred: RYEY
# true: PBS59H
# pred: PBS59H
# true: EHNU
# pred: EHNU
# true: BWR6Y
# pred: BWR6Y
# true: VY499K
# pred: VY499K
# true: TH9WY
# pred: TH9WY
# true: 3PW56
# pred: 3PW56
# true: 5RP49R
# pred: 5RP49R
# true: RYPK
# pred: RYPK
# true: 88WP
# pred: 88WP
# true: 8UX6UN
# pred: 8UX6UN
# true: XPHDSA
# pred: XPHDSA
# true: 6JDX
# pred: 6JDX
# true: WJXMAH
# pred: WJXMAH
# true: EXWMBP
# pred: EXWMBP
# true: U8YN
# pred: U8YN
# true: K3K5P
# pred: K3K5P
# true: 345P
# pred: 345P
# true: 33CD
# pred: 33CD
# true: V6KWB
# pred: V6KWB
# true: VENTB9
# pred: VENTB9
# true: VWERTP
# pred: VWERTP
# true: JHB6
# pred: JHB6
# true: 5CWPM
# pred: 5CWPM
# true: WYCR
# pred: WYCR
# true: 5VX9
# pred: 5VX9
# true: DEAXHM
# pred: DEAXHM
# true: J8E5Y
# pred: J8E5Y
# true: Y84P
# pred: Y84P
# true: 4CXVDR
# pred: 4CXVDR
# true: SW8XEE
# pred: SW8XEE
# true: 8CPHH
# pred: 8CPHH
# true: VH5PVR
# pred: VH5PVR
# true: RBTJ
# pred: RBTJ
# true: NEDK
# pred: NEDK
# true: DSPDWM
# pred: DSPDWM
# true: NJVBU
# pred: NJVBU
# true: XUWH
# pred: XUWH
# true: W6KN
# pred: W6KN
# true: 4BT8KS
# pred: 4BT8KS
# true: 68AXB9
# pred: 68AXB9
# true: WK4368
# pred: WK4368
# true: 3W4X
# pred: 3W4X
# true: EXHWN
# pred: EXHWN
# true: BWPRH
# pred: BWPRH
# true: MUPNP3
# pred: MUPNP3
# true: TJJDB
# pred: TJJDB
# true: 9NBYJ
# pred: 9NBYJ
# true: BRYR4
# pred: BRYR4
# true: JYCT
# pred: JYCT
# true: BTMYHV
# pred: BTMYHV
# true: 95PP
# pred: 95PP
# true: MDSSYD
# pred: MDSSYD
# true: SBER
# pred: SBER
# true: ARNRP
# pred: ARNRP
# true: XUDD
# pred: XUDD
# true: 9A3EVN
# pred: 9A3EVN
# true: WE6EX
# pred: WE6EX
# true: BJ8WHV
# pred: BJ8WHV
# true: 4NK83E
# pred: 4NK83E
# true: 5XMK
# pred: 5XMK
# true: CW455
# pred: CW455
# true: TPWU
# pred: TPWU
# true: D65R43
# pred: D65R43
# true: 3TMWM3
# pred: 3TMWM3
# true: MMS4W
# pred: MMS4W
# true: XSYPHN
# pred: XSYPHN
# true: D8TSR
# pred: D8TSR
# true: 633VY
# pred: 633VY
# true: V9CJ
# pred: V9CJ
# true: WKB95C
# pred: WKB95C
# true: KSHV
# pred: KSHV
# true: NRYR
# pred: NRYR
# true: 9ETMX
# pred: 9ETMX
# true: RYEBXP
# pred: RYEBXP
# true: 3TT9
# pred: 3TT9
# true: R9XE
# pred: R9XE
# true: KSVD
# pred: KSVD
# true: DBVN3
# pred: DBVN3
# true: YC9KSD
# pred: YC9KSD
# true: UMPUVN
# pred: UMPUVN
# true: REBP
# pred: REBP
# true: 8HBM3U
# pred: 8HBM3U
# true: 9PK4HP
# pred: 9PK4HP
# true: HNXUTS
# pred: HNXUTS
# true: 3T33
# pred: 3T33
# true: WCXV
# pred: WCXV
# true: XE5BXD
# pred: XE5BXD
# true: U4HM3
# pred: U4HM3
# true: 68Y5
# pred: 68Y5
# true: TCDH3
# pred: TCDH3
# true: 5P5WK6
# pred: 5P5WK6
# true: JACDXK
# pred: JACDXK
# true: 356YHM
# pred: 356YHM
# true: K8PE
# pred: K8PE
# true: S3UJRY
# pred: S3UJRY
# true: M8RHM
# pred: M8RHM
# true: 6JD5B4
# pred: 6JD5B4
# true: BBRS
# pred: BBRS
# true: P8PPSK
# pred: P8PPSK
# true: UYXB
# pred: UYXB
# true: BNVCPS
# pred: BNVCPS
# true: SSADHU
# pred: SSADHU
# true: BDKY
# pred: BDKY
# true: WXUD
# pred: WXUD
# true: 4UWV
# pred: 4UWV
# true: YJMX
# pred: YJMX
# true: USETTX
# pred: USETTX
# true: J8UA
# pred: J8UA
# true: JBPUH
# pred: JBPUH
# true: MCXU
# pred: MCXU
# true: J4TTV
# pred: J4TTV
# true: 9MYB
# pred: 9MYB
# true: D33WT5
# pred: D33WT5
# true: KYRYA4
# pred: KYRYA4
# true: J6XUH
# pred: J6XUH
# true: WP5JX
# pred: WP5JX
# true: HBXAPS
# pred: HBXAPS
# true: V8HSN3
# pred: V8HSN3
# true: CUWHPW
# pred: CUWHPW
# true: VCR5
# pred: VCR5
# true: 8UY6
# pred: 8UY6
# true: HSBJ
# pred: HSBJ
# true: X5AWAA
# pred: X5AWAA
# true: E4M8KC
# pred: E4M8KC
# true: W3YV
# pred: W3YV
# true: UTCP
# pred: UTCP
# true: XUJ3R4
# pred: XUJ3R4
# true: KR5P
# pred: KR5P
# true: NE68
# pred: NE68
# true: 55SEMN
# pred: 55SEMN
# true: 48RSV
# pred: 48RSV
# true: XDJ5
# pred: XDJ5
# true: SKS5K
# pred: SKS5K
# true: 68EU3A
# pred: 68EU3A
# true: J3H5
# pred: J3H5
# true: SHEWS
# pred: SHEWS
# true: 449PWC
# pred: 449PWC
# true: 8YW6B6
# pred: 8YW6B6
# true: RA9556
# pred: RA9556
# true: KW44
# pred: KW44
# true: BWR6TJ
# pred: BWR6TJ
# true: 3DJ5M
# pred: 3DJ5M
# true: XRCWB5
# pred: XRCWB5
# true: YRYC
# pred: YRYC
# true: TDC9
# pred: TDC9
# true: WWJH
# pred: WWJH
# true: MYE9
# pred: MYE9
# true: MAABK
# pred: MAABK
# true: J4ET4
# pred: J4ET4
# true: VUE8K
# pred: VUE8K
# true: XAPHS
# pred: XAPHS
# true: NYNU
# pred: NYNU
# true: SXVCR
# pred: SXVCR
# true: KVPJ
# pred: KVPJ
# true: YY39YS
# pred: YY39YS
# true: V6RBC3
# pred: V6RBC3
# true: 8BE5
# pred: 8BE5
# true: CT6S4E
# pred: CT6S4E
# true: V4RMYD
# pred: V4RMYD
# true: 5DYEK
# pred: 5DYEK
# true: R5BX
# pred: R5BX
# true: XJ9MS9
# pred: XJ9MS9
# true: H6U9KH
# pred: H6U9KH
# true: 545HT8
# pred: 545HT8
# true: 56RBWE
# pred: 56RBWE
# true: 84YNSE
# pred: 84YNSE
# true: TKJB
# pred: TKJB
# true: BABKR
# pred: BABKR
# true: AP9Y5
# pred: AP9Y5
# true: X6SAP
# pred: X6SAP
# true: M9SVK
# pred: M9SVK
# true: 59CW8
# pred: 59CW8
# true: E6R8PR
# pred: E6R8PR
# true: D859
# pred: D859
# true: A9M8
# pred: A9M8
# true: RNM8
# pred: RNM8
# true: YYTX
# pred: YYTX
# true: 4JW8X
# pred: 4JW8X
# true: A3WK9E
# pred: A3WK9E
# true: KYM4
# pred: KYM4
# true: 9WXU
# pred: 9WXU
# true: 3X6YRC
# pred: 3X6YRC
# true: DWKSA
# pred: DWKSA
# true: NKD8H
# pred: NKD8H
# true: PW5JH
# pred: PW5JH
# true: SUNPCH
# pred: SUNPCH
# true: HY9PC5
# pred: HY9PC5
# true: 6PHHXS
# pred: 6PHHXS
# true: DKTN
# pred: DKTN
# true: V5YTRN
# pred: V5YTRN
# true: XUC5
# pred: XUC5
# true: BB3SM
# pred: BB3SM
# true: NS8XE
# pred: NS8XE
# true: RKRPW9
# pred: RKRPW9
# true: MRS4H
# pred: MRS4H
# true: DPHT4
# pred: DPHT4
# true: U53RDV
# pred: U53RDV
# true: KHETN
# pred: KHETN
# true: 8KDM
# pred: 8KDM
# true: W99V
# pred: W99V
# true: B8R9
# pred: B8R9
# true: D4BYP
# pred: D4BYP
# true: JVBSC
# pred: JVBSC
# true: CJUVCS
# pred: CJUVCS
# true: AY6RXB
# pred: AY6RXB
# true: YWRA
# pred: YWRA
# true: JUUHU
# pred: JUUHU
# true: CP5KER
# pred: CP5KER
# true: HXK9
# pred: HXK9
# true: XXS4D
# pred: XXS4D
# true: PNX4K
# pred: PNX4K
# true: 663S
# pred: 663S
# true: 4CTWV
# pred: 4CTWV
# true: ACXT4Y
# pred: ACXT4Y
# true: VCAW
# pred: VCAW
# true: 94DW
# pred: 94DW
# true: 8YTJER
# pred: 8YTJER
# true: VDNW
# pred: VDNW
# true: R86JS
# pred: R86JS
# true: S6CNC
# pred: S6CNC
# true: 5KT3A
# pred: 5KT3A
# true: MKEW
# pred: MKEW
# true: J5VKAX
# pred: J5VKAX
# true: 3PBUMS
# pred: 3PBUMS
# true: YR46
# pred: YR46
# true: VT68ME
# pred: VT68ME
# true: 9K6RSK
# pred: 9K6RSK
# true: UPTEXH
# pred: UPTEXH
# true: 5RRW
# pred: 5RRW
# true: ER4YC
# pred: ER4YC
# true: KWHDC
# pred: KWHDC
# true: 6UTKTW
# pred: 6UTKTW
# true: MWN8D
# pred: MWN8D
# true: VACT8K
# pred: VACT8K
# true: 6NDUD
# pred: 6NDUD
# true: ECBYPH
# pred: ECBYPH
# true: NYR8D6
# pred: NYR8D6
# true: 5DXPCD
# pred: 5DXPCD
# true: TKV5DP
# pred: TKV5DP
# true: TDXB9
# pred: TDXB9
# true: TYWEMH
# pred: TYWEMH
# true: WCR96C
# pred: WCR96C
# true: 3AJMKU
# pred: 3AJMKU
# true: J4BTKT
# pred: J4BTKT
# true: X5MVR
# pred: X5MVR
# true: VWJ6
# pred: VWJ6
# true: T9KW
# pred: T9KW
# true: JCPXC
# pred: JCPXC
# true: KT3UN
# pred: KT3UN
# true: BRCW
# pred: BRCW
# true: VB5JR
# pred: VB5JR
# true: UX8HWU
# pred: UX8HWU
# true: 9MBWP
# pred: 9MBWP
# true: CEJM
# pred: CEJM
# true: BW4T
# pred: BW4T
# true: D6ES
# pred: D6ES
# true: TDJ3EB
# pred: TDJ3EB
# true: J49W
# pred: J49W
# true: 33Y3
# pred: 33Y3
# true: 9W54BU
# pred: 9W54BU
# true: JW8PP
# pred: JW8PP
# true: MPC6H
# pred: MPC6H
# true: UC83U4
# pred: UC83U4
# true: BAR3T3
# pred: BAR3T3
# true: PCDS
# pred: PCDS
# true: VTJXX5
# pred: VTJXX5
# true: 8XED
# pred: 8XED
# true: PARDS
# pred: PARDS
# true: WDWCXV
# pred: WDWCXV
# true: 6R6UWM
# pred: 6R6UWM
# true: TXAU8
# pred: TXAU8
# true: YDMJY
# pred: YDMJY
# true: BWDCE
# pred: BWDCE
# true: 434TW6
# pred: 434TW6
# true: 6WDW
# pred: 6WDW
# true: 9HW4V
# pred: 9HW4V
# true: 6U5N
# pred: 6U5N
# true: V8V4
# pred: V8V4
# true: PXUJ
# pred: PXUJ
# true: DHKXM
# pred: DHKXM
# true: 4NDYE4
# pred: 4NDYE4
# true: 8KSKPP
# pred: 8KSKPP
# true: N6W5
# pred: N6W5
# true: Y43D3K
# pred: Y43D3K
# true: 56Y35K
# pred: 56Y35K
# true: DKHMPK
# pred: DKHMPK
# true: HT4M
# pred: HT4M
# true: BKYT
# pred: BKYT
# true: WKMJ56
# pred: WKMJ56
# true: VCA4
# pred: VCA4
# true: SN9U
# pred: SN9U
# true: 6DYN3S
# pred: 6DYN3S
# true: DP8VM
# pred: DP8VM
# true: 6K5A
# pred: 6K5A
# true: 6V59
# pred: 6V59
# true: MSCS68
# pred: MSCS68
# true: Y8H9YJ
# pred: Y8H9YJ
# true: SWVT5J
# pred: SWVT5J
# true: YCY5AA
# pred: YCY5AA
# true: E5D9
# pred: E5D9
# true: WMNKR
# pred: WMNKR
# true: VJJB9
# pred: VJJB9
# true: 6WBW59
# pred: 6WBW59
# true: AN6M
# pred: AN6M
# true: M5T8
# pred: M5T8
# true: DMH6W
# pred: DMH6W
# true: 5SX34
# pred: 5SX34
# true: 8AM34M
# pred: 8AM34M
# true: TJ6XCV
# pred: TJ6XCV
# true: 9ECYJ
# pred: 9ECYJ
# true: B385MB
# pred: B385MB
# true: EYUCT
# pred: EYUCT
# true: YH3C
# pred: YH3C
# true: A445BP
# pred: A445BP
# true: K8Y86U
# pred: K8Y86U
# true: CM8S
# pred: CM8S
# true: DABYE
# pred: DABYE
# true: SX3XN
# pred: SX3XN
# true: JS45P3
# pred: JS45P3
# true: WAND5
# pred: WAND5
# true: DX9R
# pred: DX9R
# true: KDSDYN
# pred: KDSDYN
# true: UB6EE
# pred: UB6EE
# true: C9MDKT
# pred: C9MDKT
# true: 4M4U
# pred: 4M4U
# true: PH6ABN
# pred: PH6ABN
# true: 3C6E
# pred: 3C6E
# true: JMVE9N
# pred: JMVE9N
# true: EYVA
# pred: EYVA
# true: EP6XRS
# pred: EP6XRS
# true: 9K89
# pred: 9K89
# true: JJW4
# pred: JJW4
# true: YMUHYN
# pred: YMUHYN
# true: TVPXN
# pred: TVPXN
# true: 4EP8U
# pred: 4EP8U
# true: NAJAU9
# pred: NAJAU9
# true: 4WCU9C
# pred: 4WCU9C
# true: EE6SPH
# pred: EE6SPH
# true: 9VRY
# pred: 9VRY
# true: TRNME3
# pred: TRNME3
# true: VYBW4X
# pred: VYBW4X
# true: CUKXS
# pred: CUKXS
# true: ECKSSR
# pred: ECKSSR
# true: 5J44
# pred: 5J44
# true: WC3VM6
# pred: WC3VM6
# true: 9HXU4
# pred: 9HXU4
# true: A948
# pred: A948
# true: XP9M
# pred: XP9M
# true: WVY9E
# ...
# pred: DJBPSU
# true: 4Y9T
# pred: 4Y9T
# true: NSJ49
# pred: NSJ49
# true: 4MK5T
# pred: 4MK5T
# true: DEKP
# pred: DEKP
# true: R3BEE4
# pred: R3BEE4
# true: 5BRU5K
# pred: 5BRU5K
# true: 6HTSA8
# pred: 6HTSA8
# true: MSVY
# pred: MSVY
# true: WY6WJN
# pred: WY6WJN
# true: X8D8
# pred: X8D8
# true: ER4BKW
# pred: ER4BKW
# true: YV9A
# pred: YV9A
# true: 6C48
# pred: 6C48
# true: Y4KTV
# pred: Y4KTV
# true: DH5SX
# pred: DH5SX
# true: VRUDC
# pred: VRUDC
# true: T9PKM5
# pred: T9PKM5
# true: 5UCVX
# pred: 5UCVX
# true: JTEWN
# pred: JTEWN
# true: KTTY
# pred: KTTY
# true: PTAXKN
# pred: PTAXKN
# true: K86S
# pred: K86S
# true: HH9HDK
# pred: HH9HDK
# true: JU5VJ
# pred: JU5VJ
# true: UKUAC6
# pred: UKUAC6
# true: 6JTK
# pred: 6JTK
# true: DTPXU
# pred: DTPXU
# true: WEWH
# pred: WEWH
# true: HDMEA
# pred: HDMEA
# true: NA4E
# pred: NA4E
# true: JTEWT3
# pred: JTEWT3
# true: 4W4M5J
# pred: 4W4M5J
# true: DKN5
# pred: DKN5
# true: B4XPJ
# pred: B4XPJ
# true: PKRR
# pred: PKRR
# true: RD9SHK
# pred: RD9SHK
# true: NBSJWA
# pred: NBSJWA
# true: TWDT
# pred: TWDT
# true: H6MEBH
# pred: H6MEBH
# true: J3R8
# pred: J3R8
# true: 9SS59
# pred: 9SS59
# true: JAM64
# pred: JAM64
# true: VD3MU
# pred: VD3MU
# true: 5EPMB
# pred: 5EPMB
# true: 684TS
# pred: 684TS
# true: SE8SK6
# pred: SE8SK6
# true: ND8WW
# pred: ND8WW
# true: X5PM
# pred: X5PM
# true: DJ6V
# pred: DJ6V
# true: D9S9
# pred: D9S9
# true: WTWPK
# pred: WTWPK
# true: NWEA
# pred: NWEA
# true: M6SDCU
# pred: M6SDCU
# true: PEUX
# pred: PEUX
# true: JPWRH
# pred: JPWRH
# true: 69WES
# pred: 69WES
# true: KRH6MB
# pred: KRH6MB
# true: 8J96
# pred: 8J96
# true: M8TM6S
# pred: M8TM6S
# true: 6EC5YY
# pred: 6EC5YY
# true: BMCAJ5
# pred: BMCAJ5
# true: CV5XA
# pred: CV5XA
# true: S6N5RE
# pred: S6N5RE
# true: N9UM9T
# pred: N9UM9T
# true: YXD3M
# pred: YXD3M
# true: ACVJD
# pred: ACVJD
# true: A5Y3
# pred: A5Y3
# true: V3CKA
# pred: V3CKA
# true: V58RE
# pred: V58RE
# true: REMX
# pred: REMX
# true: T8MKWN
# pred: T8MKWN
# true: RXWU9B
# pred: RXWU9B
# true: AKUAS3
# pred: AKUAS3
# true: MXK8T
# pred: MXK8T
# true: KC36
# pred: KC36
# true: HMSX8B
# pred: HMSX8B
# true: 6JACJC
# pred: 6JACJC
# true: TEMDJR
# pred: TEMDJR
# true: J9SPS
# pred: J9SPS
# true: T9K5
# pred: T9K5
# true: PUPR88
# pred: PUPR88
# true: XJUC
# pred: XJUC
# true: CTH3
# pred: CTH3
# true: N8S3
# pred: N8S3
# true: N3Y6
# pred: N3Y6
# true: MJ8V
# pred: MJ8V
# true: SB3TCP
# pred: SB3TCP
# true: TCKU
# pred: TCKU
# true: 8HVA5C
# pred: 8HVA5C
# true: PSAHY6
# pred: PSAHY6
# true: CNRWE6
# pred: CNRWE6
# true: MJDXN
# pred: MJDXN
# true: KH9S
# pred: KH9S
# true: 3EDUM5
# pred: 3EDUM5
# true: NVBU
# pred: NVBU
# true: WW585C
# pred: WW585C
# true: PAMPEE
# pred: PAMPEE
# true: 6NKTJB
# pred: 6NKTJB
# true: WVYBEU
# pred: WVYBEU
# true: TDSB
# pred: TDSB
# true: K4EKK
# pred: K4EKK
# true: WJ5XE
# pred: WJ5XE
# true: 8UDD
# pred: 8UDD
# true: HTTRW
# pred: HTTRW
# true: CB8H
# pred: CB8H
# true: M8EYM4
# pred: M8EYM4
# true: 8UE33
# pred: 8UE33
# true: P5SU6
# pred: P5SU6
# true: 8UVYRW
# pred: 8UVYRW
# true: 5CKXJ5
# pred: 5CKXJ5
# true: AXU3
# pred: AXU3
# true: XHTT
# pred: XHTT
# true: KMYM96
# pred: KMYM96
# true: EY6RW
# pred: EY6RW
# true: MXW4E
# pred: MXW4E
# true: 6Y3RP
# pred: 6Y3RP
# true: MEMH6R
# pred: MEMH6R
# true: W6WHK
# pred: W6WHK
# true: RUHXN
# pred: RUHXN
# true: 35V4KP
# pred: 35V4KP
# true: MJY6
# pred: MJY6
# true: DPSX9B
# pred: DPSX9B
# true: M5CSWS
# pred: M5CSWS
# true: HCPT
# pred: HCPT
# true: PYH8
# pred: PYH8
# true: EAKH
# pred: EAKH
# true: D4SR
# pred: D4SR
# true: RNB3VD
# pred: RNB3VD
# true: H6HEBW
# pred: H6HEBW
# true: TCRBMD
# pred: TCRBMD
# true: Y9JTA
# pred: Y9JTA
# true: 9BPX
# pred: 9BPX
# true: YWW3N6
# pred: YWW3N6
# true: VMCNU3
# pred: VMCNU3
# true: 4A5X9S
# pred: 4A5X9S
# true: 6CTEK
# pred: 6CTEK
# true: YSMHA
# pred: YSMHA
# true: UX95W
# pred: UX95W
# true: WYYWA
# pred: WYYWA
# true: AM8A
# pred: AM8A
# true: WA348
# pred: WA348
# true: XPU4
# pred: XPU4
# true: 85BNNS
# pred: 85BNNS
# true: AC9KM
# pred: AC9KM
# true: J4ACX8
# pred: J4ACX8
# true: KKR5
# pred: KKR5
# true: U9U3H
# pred: U9U3H
# true: CDEB
# pred: CDEB
# true: BMK56S
# pred: BMK56S
# true: 3DT4R3
# pred: 3DT4R3
# true: JBAX
# pred: JBAX
# true: UNEKH
# pred: UNEKH
# true: ATNTTX
# pred: ATNTTX
# true: K9PH
# pred: K9PH
# true: XY4UP5
# pred: XY4UP5
# true: WAAVYD
# pred: WAAVYD
# true: PV5X
# pred: PV5X
# true: D5KE
# pred: D5KE
# true: WRTCTA
# pred: WRTCTA
# true: 5NY4
# pred: 5NY4
# true: 5VE369
# pred: 5VE369
# true: X9ETMA
# pred: X9ETMA
# true: 9XCCHH
# pred: 9XCCHH
# true: 9E5H
# pred: 9E5H
# true: 5WRYY
# pred: 5WRYY
# true: M4EE9D
# pred: M4EE9D
# true: SHVX
# pred: SHVX
# true: 9BAEE
# pred: 9BAEE
# true: BHDP3
# pred: BHDP3
# true: YAJV4J
# pred: YAJV4J
# true: YWJD
# pred: YWJD
# true: VTKTK
# pred: VTKTK
# true: 5HKNN
# pred: 5HKNN
# true: 6VHY5K
# pred: 6VHY5K
# true: X3MXP
# pred: X3MXP
# true: 8KTWV
# pred: 8KTWV
# true: ACJPJ
# pred: ACJPJ
# true: 9583
# pred: 9583
# true: RSXYR
# pred: RSXYR
# true: J8TVE4
# pred: J8TVE4
# true: 6H9V
# pred: 6H9V
# true: VYT5N
# pred: VYT5N
# true: 3N55N
# pred: 3N55N
# true: UD5SE8
# pred: UD5SE8
# true: PV8TTY
# pred: PV8TTY
# true: W3CA
# pred: W3CA
# true: YXEVK
# pred: YXEVK
# true: VXVT
# pred: VXVT
# true: R84P9
# pred: R84P9
# true: TKDK
# pred: TKDK
# true: PN3V39
# pred: PN3V39
# true: V8RW6
# pred: V8RW6
# true: 34WH9Y
# pred: 34WH9Y
# true: DRSN9
# pred: DRSN9
# true: W88T8P
# pred: W88T8P
# true: YDPV
# pred: YDPV
# true: VBXC
# pred: VBXC
# true: UPYJ6
# pred: UPYJ6
# true: PYJAT
# pred: PYJAT
# true: UNA33
# pred: UNA33
# true: ACUY
# pred: ACUY
# true: BTJ5
# pred: BTJ5
# true: T834H
# pred: T834H
# true: MJJYP
# pred: MJJYP
# true: CKYHMM
# pred: CKYHMM
# true: 48M6
# pred: 48M6
# true: 4BXSAE
# pred: 4BXSAE
# true: B656
# pred: B656
# true: DC99
# pred: DC99
# true: 8MBRE
# pred: 8MBRE
# true: PANH
# pred: PANH
# true: R3DBT
# pred: R3DBT
# true: NNPN
# pred: NNPN
# true: 4UPM
# pred: 4UPM
# true: V9394
# pred: V9394
# true: 4XATXR
# pred: 4XATXR
# true: ANYKVX
# pred: ANYKVX
# true: 8UPR
# pred: 8UPR
# true: NW5AP
# pred: NW5AP
# true: VJCKR
# pred: VJCKR
# true: 536B
# pred: 536B
# true: HMKWB
# pred: HMKWB
# true: KBP3K
# pred: KBP3K
# true: C9TUC
# pred: C9TUC
# true: YDRSS
# pred: YDRSS
# true: DT8X
# pred: DT8X
# true: 9DM33Y
# pred: 9DM33Y
# true: PBSEA
# pred: PBSEA
# true: 5HP6
# pred: 5HP6
# true: 9T4MP
# pred: 9T4MP
# true: JXS8
# pred: JXS8
# true: HMXC
# pred: HMXC
# true: 46B4W5
# pred: 46B4W5
# true: D3T55R
# pred: D3T55R
# true: 4EB46
# pred: 4EB46
# true: 55XD63
# pred: 55XD63
# true: YS39P
# pred: YS39P
# true: 3KHHC
# pred: 3KHHC
# true: 6DS3R3
# pred: 6DS3R3
# true: AC9E
# pred: AC9E
# true: 5YETJ
# pred: 5YETJ
# true: CW5SCB
# pred: CW5SCB
# true: 3BDUPV
# pred: 3BDUPV
# true: B5A98
# pred: B5A98
# true: 3HWR
# pred: 3HWR
# true: UNSYBU
# pred: UNSYBU
# true: TJA8
# pred: TJA8
# true: JDCCR
# pred: JDCCR
# true: 8CS85
# pred: 8CS85
# true: YMHY
# pred: YMHY
# true: R8JNVP
# pred: R8JNVP
# true: CAKRJM
# pred: CAKRJM
# true: U8UA
# pred: U8UA
# true: R6Y8
# pred: R6Y8
# true: 545HW3
# pred: 545HW3
# true: CVB6T
# pred: CVB6T
# true: MNSEWV
# pred: MNSEWV
# true: DE89
# pred: DE89
# true: 3JR6B
# pred: 3JR6B
# true: AK36RT
# pred: AK36RT
# true: T4HS
# pred: T4HS
# true: N6B4HU
# pred: N6B4HU
# true: T3YS5A
# pred: T3YS5A
# true: U9AHE9
# pred: U9AHE9
# true: 3M8RD
# pred: 3M8RD
# true: HP6S
# pred: HP6S
# true: 99BH6
# pred: 99BH6
# true: S54MA
# pred: S54MA
# true: RJMTUW
# pred: RJMTUW
# true: ETYDE
# pred: ETYDE
# true: KTS3UN
# pred: KTS3UN
# true: H6T6E6
# pred: H6T6E6
# true: TK4VM
# pred: TK4VM
# true: 36A4WR
# pred: 36A4WR
# true: 6TMAC
# pred: 6TMAC
# true: R3CW
# pred: R3CW
# true: YMXMD
# pred: YMXMD
# true: SCR86E
# pred: SCR86E
# true: JYSJ
# pred: JYSJ
# true: WHAEAK
# pred: WHAEAK
# true: DRRYSS
# pred: DRRYSS
# true: REKM
# pred: REKM
# true: YDHVH
# pred: YDHVH
# true: CK3D4N
# pred: CK3D4N
# true: DVC545
# pred: DVC545
# true: S8KH4
# pred: S8KH4
# true: CYS3
# pred: CYS3
# true: UNTKP3
# pred: UNTKP3
# true: 5MRB
# pred: 5MRB
# true: JDUPUB
# pred: JDUPUB
# true: 5J6BUV
# pred: 5J6BUV
# true: D3SJE
# pred: D3SJE
# true: 6VKW4
# pred: 6VKW4
# true: KKNC
# pred: KKNC
# true: AA9K
# pred: AA9K
# true: V4V9E
# pred: V4V9E
# true: 8MY9P
# pred: 8MY9P
# true: DMRJN
# pred: DMRJN
# true: JCHW
# pred: JCHW
# true: RVW6P9
# pred: RVW6P9
# true: DRNKY
# pred: DRNKY
# true: MBHKH
# pred: MBHKH
# true: 35KT
# pred: 35KT
# true: DHSC
# pred: DHSC
# true: CDP4CT
# pred: CDP4CT
# true: 4UTM
# pred: 4UTM
# true: 6K6H9W
# pred: 6K6H9W
# true: HW69CD
# pred: HW69CD
# true: 3DECUN
# pred: 3DECUN
# true: NNU83D
# pred: NNU83D
# true: Y9CJD
# pred: Y9CJD
# true: RP4N
# pred: RP4N
# true: MT8A5
# pred: MT8A5
# true: 4C39
# pred: 4C39
# true: U444
# pred: U444
# true: 5JWY
# pred: 5JWY
# true: TWVW
# pred: TWVW
# true: AY4PBP
# pred: AY4PBP
# true: V4V5N
# pred: V4V5N
# true: 33TUPT
# pred: 33TUPT
# true: HNDRR9
# pred: HNDRR9
# true: MV5JWR
# pred: MV5JWR
# true: A3UBK
# pred: A3UBK
# true: YH9U9
# pred: YH9U9
# true: DCYB
# pred: DCYB
# true: 5NKCCM
# pred: 5NKCCM
# true: K3A3X9
# pred: K3A3X9
# true: Y9NK54
# pred: Y9NK54
# true: 5UJMDT
# pred: 5UJMDT
# true: SAYXB
# pred: SAYXB
# true: 4TPC
# pred: 4TPC
# true: 8KS8J
# pred: 8KS8J
# true: NNDHKW
# pred: NNDHKW
# true: VRDVM
# pred: VRDVM
# true: 48NH9
# pred: 48NH9
# true: NMN9
# pred: NMN9
# true: 5UADM
# pred: 5UADM
# true: K66HM
# pred: K66HM
# true: TTST
# pred: TTST
# true: KTC5
# pred: KTC5
# true: 3EUWW
# pred: 3EUWW
# true: WSSSM
# pred: WSSSM
# true: UDHK
# pred: UDHK
# true: TBJP
# pred: TBJP
# true: EX9J
# pred: EX9J
# true: BMXS
# pred: BMXS
# true: NN6A8
# pred: NN6A8
# true: XJXRWT
# pred: XJXRWT
# true: 9S58N
# pred: 9S58N
# true: 4PSP
# pred: 4PSP
# true: VESU
# pred: VESU
# true: TS5C8
# pred: TS5C8
# true: BUA8
# pred: BUA8
# true: 6DDR3
# pred: 6DDR3
# true: 3V8568
# pred: 3V8568
# true: DUMU
# pred: DUMU
# true: 9WEKB
# pred: 9WEKB
# true: 89WYD
# pred: 89WYD
# true: RXJAM
# pred: RXJAM
# true: URRAY8
# pred: URRAY8
# true: MNMUW
# pred: MNMUW
# true: PXX9
# pred: PXX9
# true: AXS4BM
# pred: AXS4BM
# true: VATHPK
# pred: VATHPK
# true: 56AP
# pred: 56AP
# true: AVNKY
# pred: AVNKY
# true: AN4WR
# pred: AN4WR
# true: K5T6
# pred: K5T6
# true: 5YR3
# pred: 5YR3
# true: 8XJYJP
# pred: 8XJYJP
# true: D8X8XK
# pred: D8X8XK
# true: NHUHTR
# pred: NHUHTR
# true: WUTS6U
# pred: WUTS6U
# true: JMXCCV
# pred: JMXCCV
# true: SH5W6
# pred: SH5W6
# true: 4T8M
# pred: 4T8M
# true: NXXJB
# pred: NXXJB
# true: WECCW
# pred: WECCW
# true: TCNKU
# pred: TCNKU
# true: DB3B
# pred: DB3B
# true: NSK33
# pred: NSK33
# true: BB5K
# pred: BB5K
# true: NC9P5
# pred: NC9P5
# true: SX6KD
# pred: SX6KD
# true: VMRPW6
# pred: VMRPW6
# true: VR8J
# pred: VR8J
# true: W48C
# pred: W48C
# true: XBCKPM
# pred: XBCKPM
# true: NXHPK
# pred: NXHPK
# true: 5EBE
# pred: 5EBE
# true: JB65VS
# pred: JB65VS
# true: A8TU
# pred: A8TU
# true: T3S4PA
# pred: T3S4PA
# true: UDES9
# pred: UDES9
# true: MJB63U
# pred: MJB63U
# true: CVNY
# pred: CVNY
# true: BDSN6
# pred: BDSN6
# true: PJ4T4
# pred: PJ4T4
# true: EVYSRK
# pred: EVYSRK
# true: CUC8PM
# pred: CUC8PM
# true: 4E58
# pred: 4E58
# true: WXRH
# pred: WXRH
# true: BWCHKM
# pred: BWCHKM
# true: KAEWES
# pred: KAEWES
# true: XESC
# pred: XESC
# true: E35ND9
# pred: E35ND9
# true: 9Y6NN
# pred: 9Y6NN
# true: NUURS
# pred: NUURS
# true: MEMX
# pred: MEMX
# true: NB85HN
# pred: NB85HN
# true: PVMJ
# pred: PVMJ
# true: RKXUJ
# pred: RKXUJ
# true: JMTSC
# pred: JMTSC
# true: DJXP4
# pred: DJXP4
# true: RJRH
# pred: RJRH
# true: 9WS5H6
# pred: 9WS5H6
# true: NJS5D
# pred: NJS5D
# true: AR69S
# pred: AR69S
# true: PMT86
# pred: PMT86
# true: EX6H
# pred: EX6H
# true: P9WB
# pred: P9WB
# true: 9C59M
# pred: 9C59M
# true: TMKA
# pred: TMKA
# true: B39N8W
# pred: B39N8W
# true: SMWC
# pred: SMWC
# true: 8ANUC3
# pred: 8ANUC3
# true: 6TJ6
# pred: 6TJ6
# true: 4SNUTS
# pred: 4SNUTS
# true: BD9N9
# pred: BD9N9
# true: DSKS
# pred: DSKS
# true: 3ATHX5
# pred: 3ATHX5
# true: W35NU
# pred: W35NU
# true: KKUMW
# pred: KKUMW
# true: 556WY
# pred: 556WY
# true: TPKR
# pred: TPKR
# true: 55B3V
# pred: 55B3V
# true: X4TRD
# pred: X4TRD
# true: YHJY
# pred: YHJY
# true: WTNS
# pred: WTNS
# true: 9NT35
# pred: 9NT35
# true: WKPR
# pred: WKPR
# true: N9YSWN
# pred: N9YSWN
# true: PXJW
# pred: PXJW
# true: PE4KVE
# pred: PE4KVE
# true: A5DCC
# pred: A5DCC
# true: KJNY3
# pred: KJNY3
# true: XSYE3M
# pred: XSYE3M
# true: BNDCK
# pred: BNDCK
# true: 89KSN
# pred: 89KSN
# true: 4YSWE
# pred: 4YSWE
# true: 3TMT
# pred: 3TMT
# true: BU8N
# pred: BU8N
# true: 4TUH
# pred: 4TUH
# true: BK9CK
# pred: BK9CK
# true: UNSSK
# pred: UNSSK
# true: 3V4V
# pred: 3V4V
# true: BKJ5K
# pred: BKJ5K
# true: M4X8S
# pred: M4X8S
# true: DC3CBE
# pred: DC3CBE
# true: W6J3N
# pred: W6J3N
# true: H3JU3X
# pred: H3JU3X
# true: JBXBBH
# pred: JBXBBH
# true: YB3U56
# pred: YB3U56
# true: BMM5
# pred: BMM5
# true: XPPB
# pred: XPPB
# true: JEMW
# pred: JEMW
# true: C83HR
# pred: C83HR
# true: 9J4HMP
# pred: 9J4HMP
# true: P6JV84
# pred: P6JV84
# true: XVJS
# pred: XVJS
# true: TPA5AH
# pred: TPA5AH
# true: 6WYVP4
# pred: 6WYVP4
# true: DX6HHW
# pred: DX6HHW
# true: AXK5E
# pred: AXK5E
# true: J5YY5R
# pred: J5YY5R
# true: R84BM
# pred: R84BM
# true: XWA5
# pred: XWA5
# true: EN68
# pred: EN68
# true: K9C3UJ
# pred: K9C3UJ
# true: XYVBDW
# pred: XYVBDW
# true: YTMBM
# pred: YTMBM
# true: UV89
# pred: UV89
# true: J6VEP
# pred: J6VEP
# true: 68RT
# pred: 68RT
# true: 9TUDS
# pred: 9TUDS
# true: 6XJHMM
# pred: 6XJHMM
# true: 8KDR
# pred: 8KDR
# true: 493U
# pred: 493U
# true: ADXVUH
# pred: ADXVUH
# true: 5BA93C
# pred: 5BA93C
# true: 9AYV
# pred: 9AYV
# true: RBX3S
# pred: RBX3S
# true: CXPU
# pred: CXPU
# true: 49R6
# pred: 49R6
# true: W5TBXK
# pred: W5TBXK
# true: 4RN5
# pred: 4RN5
# true: 5EMA
# pred: 5EMA
# true: HWYDXW
# pred: HWYDXW
# true: VB6R5
# pred: VB6R5
# true: J596VK
# pred: J596VK
# true: EYU8
# pred: EYU8
# true: 9XMD
# pred: 9XMD
# true: TWYHV
# pred: TWYHV
# true: BUTUC
# pred: BUTUC
# true: 399VRW
# pred: 399VRW
# true: 95E5N
# pred: 95E5N
# true: 6RX3B
# pred: 6RX3B
# true: SHXSM
# pred: SHXSM
# true: R3C3
# pred: R3C3
# true: YETJH
# pred: YETJH
# true: VDUN3
# pred: VDUN3
# true: UUK6
# pred: UUK6
# true: E8BW
# pred: E8BW
# true: SPUWR6
# pred: SPUWR6
# true: AHS3SJ
# pred: AHS3SJ
# true: E8Y6
# pred: E8Y6
# true: EMVAY
# pred: EMVAY
# true: 8PPNXR
# pred: 8PPNXR
# true: 9WYSK
# pred: 9WYSK
# true: H5U6
# pred: H5U6
# true: 99R9WY
# pred: 99R9WY
# true: 9TAUTK
# pred: 9TAUTK
# true: RCAC3B
# pred: RCAC3B
# true: JJTT
# pred: JJTT
# true: 39AJBY
# pred: 39AJBY
# true: 454T
# pred: 454T
# true: WYTK
# pred: WYTK
# true: ARD4C
# pred: ARD4C
# true: EAW9
# pred: EAW9
# true: TV9PJP
# pred: TV9PJP
# true: 9CBSAH
# pred: 9CBSAH
# true: REJ3DX
# pred: REJ3DX
# true: MRJ6
# pred: MRJ6
# true: MCHMS
# pred: MCHMS
# true: DBE5W6
# pred: DBE5W6
# true: R43PTU
# pred: R43PTU
# true: BM5SUD
# pred: BM5SUD
# true: KJ63
# pred: KJ63
# true: 9YR9J
# pred: 9YR9J
# true: CU6TTY
# pred: CU6TTY
# true: 39XUHY
# pred: 39XUHY
# true: DCED8
# pred: DCED8
# true: U9YXV
# pred: U9YXV
# true: HJMWVX
# pred: HJMWVX
# true: VWT4X
# pred: VWT4X
# true: UBVN
# pred: UBVN
# true: UPKP3
# pred: UPKP3
# true: NY98
# pred: NY98
# true: HBYUP
# pred: HBYUP
# true: EWPPV
# pred: EWPPV
# true: HY8SW
# pred: HY8SW
# true: TAJM9C
# pred: TAJM9C
# true: R9MD3V
# pred: R9MD3V
# true: VWURUB
# pred: VWURUB
# true: YYKSN
# pred: YYKSN
# true: YVPVU
# pred: YVPVU
# true: DUKAX
# pred: DUKAX
# true: XJMSVN
# pred: XJMSVN
# true: KEAKM
# pred: KEAKM
# true: 8C8S
# pred: 8C8S
# true: JP499K
# pred: JP499K
# true: 9EPWJ6
# pred: 9EPWJ6
# true: EDXNB8
# pred: EDXNB8
# true: RXP6
# pred: RXP6
# true: U8EJ
# pred: U8EJ
# true: DMKY
# pred: DMKY
# true: 4BTC8
# pred: 4BTC8
# true: 6MRYHE
# pred: 6MRYHE
# true: UKXTU
# pred: UKXTU
# true: JA5K
# pred: JA5K
# true: MJU88P
# pred: MJU88P
# true: Y9EPD
# pred: Y9EPD
# true: E9R5WT
# pred: E9R5WT
# true: WY86
# pred: WY86
# true: P3MH
# pred: P3MH
# true: JV59KK
# pred: JV59KK
# true: SYKYR
# pred: SYKYR
# true: XJW55H
# pred: XJW55H
# true: 3JJ4
# pred: 3JJ4
# true: KTNU8Y
# pred: KTNU8Y
# true: HU4DH3
# pred: HU4DH3
# true: JM8TN
# pred: JM8TN
# true: ADHM6
# pred: ADHM6
# true: MEMPJA
# pred: MEMPJA
# true: T3CAWP
# pred: T3CAWP
# true: HPTRPJ
# pred: HPTRPJ
# true: 946Y9
# pred: 946Y9
# true: 44A65E
# pred: 44A65E
# true: U5UR9
# pred: U5UR9
# true: RSHUK
# pred: RSHUK
# true: JWUY9T
# pred: JWUY9T
# true: 95NN
# pred: 95NN
# true: V955R
# pred: V955R
# true: ERJTS
# pred: ERJTS
# true: KATC4
# pred: KATC4
# true: CKHAD
# pred: CKHAD
# true: D6BEX4
# pred: D6BEX4
# true: D58CY
# pred: D58CY
# true: XTNX
# pred: XTNX
# true: E3B8
# pred: E3B8
# true: W6PBR
# pred: W6PBR
# true: 3KP8T
# pred: 3KP8T
# true: BKSJ
# pred: BKSJ
# true: 9JWN
# pred: 9JWN
# true: MW4NX9
# pred: MW4NX9
# true: SBV8
# pred: SBV8
# true: NN8D
# pred: NN8D
# true: BVSCRH
# pred: BVSCRH
# true: TSMP
# pred: TSMP
# true: 4NDJ
# pred: 4NDJ
# true: TXCRP9
# pred: TXCRP9
# true: U35XV
# pred: U35XV
# true: E58BH
# pred: E58BH
# true: JYXBD
# pred: JYXBD
# true: TAYX3
# pred: TAYX3
# true: DMUHU
# pred: DMUHU
# true: XH4PX
# pred: XH4PX
# true: ES4VS
# pred: ES4VS
# true: 66WBJ6
# pred: 66WBJ6
# true: 93V8E
# pred: 93V8E
# true: YPDK
# pred: YPDK
# true: 4ENA
# pred: 4ENA
# true: M84S
# pred: M84S
# true: RPRP
# pred: RPRP
# true: B6M4X
# pred: B6M4X
# true: DH9YS
# pred: DH9YS
# true: XTSBW
# pred: XTSBW
# true: 9K46E9
# pred: 9K46E9
# true: 34WPM
# pred: 34WPM
# true: WVHJ9R
# pred: WVHJ9R
# true: RC6MR
# pred: RC6MR
# true: E4R4UB
# pred: E4R4UB
# true: HK4N
# pred: HK4N
# true: YSVC
# pred: YSVC
# true: N8XMJ
# pred: N8XMJ
# true: YJ5TVT
# pred: YJ5TVT
# true: 4VCW
# pred: 4VCW
# true: U4NAVE
# pred: U4NAVE
# true: NPDSMY
# pred: NPDSMY
# true: J6K3V
# pred: J6K3V
# true: DMT4
# pred: DMT4
# true: XJUVW
# pred: XJUVW
# true: ARW9
# pred: ARW9
# true: 4XE4XS
# pred: 4XE4XS
# true: BM3HS
# pred: BM3HS
# true: EKER
# pred: EKER
# true: 9MW49P
# pred: 9MW49P
# true: T98B6V
# pred: T98B6V
# true: HYYX
# pred: HYYX
# true: YY4VE
# pred: YY4VE
# true: 5HMM6
# pred: 5HMM6
# true: 3PSCY
# pred: 3PSCY
# true: SDBCE
# pred: SDBCE
# true: HU3APM
# pred: HU3APM
# true: RX4B5
# pred: RX4B5
# true: 9P85P8
# pred: 9P85P8
# true: 59SPVU
# pred: 59SPVU
# true: URJB5
# pred: URJB5
# true: DNSUR
# pred: DNSUR
# true: HRBBRU
# pred: HRBBRU
# true: XD4M3P
# pred: XD4M3P
# true: MWPB
# pred: MWP
# <PIL.Image.Image image mode=RGB size=200x50 at 0x7F44783A4340>

# %%
torch.save(model, 'ctc.pth')
